# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !pip install gradio ultralytics pillow numpy opencv-python segment-anything-hq pandas

# !wget -O /content/sam_hq_vit_h.pth https://huggingface.co/lkeab/hq-sam/resolve/main/sam_hq_vit_h.pth
# Out:
# ...
# --2025-11-25 19:30:50--  https://huggingface.co/lkeab/hq-sam/resolve/main/sam_hq_vit_h.pth
# Resolving huggingface.co (huggingface.co)... 3.165.160.59, 3.165.160.11, 3.165.160.12, ...
# Connecting to huggingface.co (huggingface.co)|3.165.160.59|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
from ui import demo
demo.launch(share=True)
# Out:
# Rerunning server... use `close()` to stop if you need to change `launch()` parameters.
# ----
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://30164c7f431c59744a.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://30164c7f431c59744a.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
