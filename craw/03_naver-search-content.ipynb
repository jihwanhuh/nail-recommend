# %% [markdown]
# # 네이버 검색 + 블로그 본문 스크랩

# %% [markdown]
# ## 정보 입력 / 전역 설정

# %% [markdown]
# ### 환경 변수

# %%
# 실행 순번 - 경로에 사용
RUN_INDEX = 1                 # !!중요!! - 실행=파일명 순번 => 수동 업데이트
keyword = '네일 라운드'            # 검색 키워드
search_keyword = '네일 "라운드" -스퀘어 -오발 -오벌 -아몬드 -스퀘어오벌 -스퀘어오발'      # 검색창에 넣을 실제 값
# 네일 "라운드" -스퀘어 -오발 -오벌 -아몬드 -스퀘어오벌 -스퀘어오발

# --- 검색 일자 ---
start_date = '20220101'
end_date = ''                 # 입력 안 하면 오늘 날짜로 세팅

# --- 스크롤 횟수 ---
scroll_times = 30              # 스크롤 횟수

# --- 다운로드 옵션 ---
IS_SAVE_CSV = True            # CSV(엑셀용) 저장 여부
IS_SAVE_IMAGES = True         # 이미지 저장 여부

# --- 파일 다운로드 경로 (ROOT) --
ROOT_DOWNLOAD_DIR = 'craw-download-file'

# %% [markdown]
# ### 검색 키워드 입력

# %%
# 단일 키워드

# 다중 키워드 (여러번 검색 수행) - 비어 있다면, 단일 키워드로 수행
search_keywords = [
    # # 1) 기본/일반 네일 (베이스 분포용)
    # "네일 추천",
    # "네일 디자인",
    # "셀프네일 디자인",
    # "데일리 네일",
    # "직장인 네일",

    # # 2) 쉐입 중심
    # "라운드 네일 디자인",
    # "오벌 네일 디자인",
    # "스퀘어 네일 디자인",
    # "스퀘어오벌 네일",
    # "아몬드 네일 디자인",

    # # 3) 길이·손 특징 중심
    # "짧은 손톱 네일",
    # "짧은손톱 셀프네일",
    # "긴 손톱 네일",
    # "손가락 길어보이는 네일",
    # "손이 예뻐보이는 네일",
]

# %% [markdown]
# ## 함수 정의

# %% [markdown]
# ### 모듈 import

# %%
import os
import re
import requests
from datetime import datetime
from urllib.parse import urljoin

import pandas as pd
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
import mimetypes

# %% [markdown]
# ### 파일 경로

# %%
## 파일 경로 : 일자 + 실행 순번 + 검색어 or multi

today_date = datetime.now().strftime("%Y%m%d")

def sanitize_keyword(kw: str) -> str:
    """파일/폴더명으로 쓸 수 있게 키워드 정제 """
    if not isinstance(kw, str):
        kw = str(kw)
    kw = kw.strip().strip('"').strip("'")
    # 파일명에 쓸 수 없는 문자 제거
    kw = re.sub(r'[\\/:*?"<>|]', '_', kw)
    # 너무 길면 잘라내기
    if len(kw) == 0:
        kw = "keyword"
    return kw

SAFE_KEYWORD = sanitize_keyword(keyword)

SUB_NAME = f"{today_date}_{RUN_INDEX:02d}_{SAFE_KEYWORD}"

CSV_PATH = os.path.join(ROOT_DOWNLOAD_DIR, f"{SUB_NAME}.csv")
IMAGE_DIR = os.path.join(ROOT_DOWNLOAD_DIR, SUB_NAME)

# %% [markdown]
# ### 날짜 정규화

# %%
import re
from datetime import datetime, timedelta, timezone

KST = timezone(timedelta(hours=9))

_abs = re.compile(r"^\s*(\d{4})\.(\d{1,2})\.(\d{1,2})\.?\s*$")
_m  = re.compile(r"(\d+)\s*분\s*전")
_h  = re.compile(r"(\d+)\s*시간\s*전")
_d  = re.compile(r"(\d+)\s*일\s*전")
_w  = re.compile(r"(\d+)\s*주\s*전")
_not_date_tail = re.compile(r"(?:단|TOP),\s*$")        # 예: "A34면 1단," , "A30면 TOP,"

def _ymd(dt: datetime) -> str:
    # Python/Excel 공통 인식 포맷: YYYY-MM-DD
    return f"{dt.year:04d}-{dt.month:02d}-{dt.day:02d}"

def normalize_news_date(texts, now: datetime | None = None) -> str | None:
    # 변환 실패 대비: 원본 첫 값 보관
    original_first = texts if isinstance(texts, str) else (texts[0] if texts else None)

    if isinstance(texts, str):
        texts = [texts]
    now = now or datetime.now(KST)

    for t in texts:
        if not t:
            continue
        s = t.strip()

        # 지면/면·단, TOP 꼬리면 스킵
        if _not_date_tail.search(s):
            continue

        # 절대형
        m = _abs.match(s)
        if m:
            y, mo, d = map(int, m.groups())
            return f"{y:04d}-{mo:02d}-{d:02d}"

        # 상대형
        if (mm := _h.search(s)): # 분
            return _ymd(now - timedelta(minutes=int(mm.group(1))))
        if (mh := _h.search(s)): # 시간
            return _ymd(now - timedelta(hours=int(mh.group(1))))
        if (md := _d.search(s)): # 일
            return _ymd(now - timedelta(days=int(md.group(1))))
        if (mw := _w.search(s)): # 주
            return _ymd(now - timedelta(weeks=int(mw.group(1))))

    # 날짜형 변환이 안되면 첫 번째 값 반환
    return original_first

# %% [markdown]
# ### 검색 결과 카드 한 개에서 정보 추출

# %%
def get_content(review):
    condic = {}

    title_css  = (
        "span.sds-comps-text.sds-comps-text-ellipsis.sds-comps-text-ellipsis-1"
        ".sds-comps-text-type-headline1.sds-comps-text-weight-sm"
    )
    text_css   = (
        "span.sds-comps-text-type-body1"
    )
    viewer_css = (
        "div.sds-comps-horizontal-layout.sds-comps-inline-layout"
        ".sds-comps-profile-info-title"
    )
    date_css   = (
        "span.sds-comps-text.sds-comps-text-type-body2"
        ".sds-comps-text-weight-sm.sds-comps-profile-info-subtext"
    )
    link_css   = 'a[href*="blog.naver.com"]'

    condic['writer'] = review.find_element(By.CSS_SELECTOR, viewer_css) \
                             .get_attribute('innerText').strip()
    condic['title'] = review.find_element(By.CSS_SELECTOR, title_css) \
                             .get_attribute('innerText').strip()
    condic['text'] = review.find_element(By.CSS_SELECTOR, text_css) \
                            .get_attribute('innerText').strip()
    condic['date'] = normalize_news_date(
        review.find_element(By.CSS_SELECTOR, date_css)
              .get_attribute('innerText').strip()
    )
    try:
        condic['link'] = review.find_element(By.CSS_SELECTOR, link_css) \
                                .get_attribute('href')
    except Exception:
        condic['link'] = ''
        print(f"condic['link'] -> 추출오류 : {condic['title']}")

    return condic

# %% [markdown]
# ### 블로그 본문 크롤링 + 이미지 저장

# %%
def crawl_blog_content(url: str, search_idx: int,
                       image_dir: str,
                       is_download_images: bool = True):

    COMMON_HEADERS = {"User-Agent": "Mozilla/5.0"}

    resp = requests.get(url, headers=COMMON_HEADERS)
    resp.raise_for_status()
    soup = BeautifulSoup(resp.text, "html.parser")

    # iframe 찾기
    iframe = soup.select_one("iframe#mainFrame")
    if iframe is None:
        for f in soup.find_all("iframe"):
            src = f.get("src") or ""
            if "PostView" in src:
                iframe = f
                break

    if iframe is None:
        print(f"[WARN] iframe 없음 → {url}")
        return {"title": "", "full_text": "", "image_count": 0}

    inner_src = iframe.get("src")
    inner_url = urljoin(resp.url, inner_src)

    # iframe 안쪽 요청
    resp2 = requests.get(inner_url, headers=COMMON_HEADERS)
    resp2.raise_for_status()
    soup2 = BeautifulSoup(resp2.text, "html.parser")

    # 제목
    title_tag = soup2.find("title")
    title = title_tag.get_text(strip=True) if title_tag else ""

    # 본문 텍스트
    paragraphs = [p.get_text(" ", strip=True) for p in soup2.find_all("p")]
    full_text = "\n".join(paragraphs)

    if not full_text.strip():
        main_div = soup2.select_one("div.se-main-container")
        if main_div:
            paragraphs = [
                p.get_text(" ", strip=True)
                for p in main_div.find_all(["p", "span"])
            ]
            full_text = "\n".join(paragraphs)

    # 이미지 다운로드
    image_count = 0
    if is_download_images:
        content = (
            soup2.select_one("div.se-main-container")
            or soup2.select_one("#postViewArea")
            or soup2
        )
        img_tags = content.find_all("img")

        os.makedirs(image_dir, exist_ok=True)

        allowed_hosts = ("postfiles.pstatic.net", "blogfiles.pstatic.net")

        for img_idx, img in enumerate(img_tags, start=1):
            src = img.get("data-origin") or img.get("data-src") or img.get("src")
            if not src:
                continue

            if not any(h in src for h in allowed_hosts):
                continue

            if src.startswith("//"):
                src = "https:" + src
            elif src.startswith("/"):
                src = urljoin(inner_url, src)
            if src.startswith("data:"):
                continue

            hi_src = src
            if "type=w80_blur" in src:
                hi_src = src.replace("type=w80_blur", "type=w966")

            img_headers = {
                "User-Agent": "Mozilla/5.0",
                "Referer": inner_url,
            }

            img_resp = None
            for candidate in [hi_src, src]:
                try:
                    r = requests.get(candidate, headers=img_headers, timeout=10)
                    r.raise_for_status()
                    img_resp = r
                    break
                except Exception:
                    img_resp = None

            if img_resp is None:
                continue

            content_type = img_resp.headers.get("Content-Type", "")
            if "image" not in content_type:
                continue

            if not is_download_images:
                image_count += 1
                continue

            ext = mimetypes.guess_extension(content_type.split(";")[0]) or ".jpg"

            # IMG_{검색결과순번 4자리}_{본문내 이미지순번 4자리}
            filename = os.path.join(
                image_dir,
                f"IMG_{search_idx:04d}_{img_idx:04d}{ext}"
            )

            with open(filename, "wb") as f:
                f.write(img_resp.content)

            image_count += 1

    return {
        "title": title,
        "full_text": full_text,
        "image_count": image_count,
    }


def enrich_with_blog_contents(df_search: pd.DataFrame) -> pd.DataFrame:
    """
    1번 검색 df 기준:
    - title 덮어쓰기 (블로그 실제 제목)
    - full_text 열 추가
    - image_count 열 추가
    """

    df = df_search.copy()
    df["full_text"] = ""
    df["image_count"] = 0

    for idx, row in df.iterrows():
        url = row.get("link", "")
        if not isinstance(url, str) or not url.strip():
            continue

        search_idx = idx + 1
        print(f"[{search_idx}/{len(df)}] {url}")

        info = crawl_blog_content(
            url=url,
            search_idx=search_idx,
            image_dir=IMAGE_DIR,
            is_download_images=IS_SAVE_IMAGES
        )

        df.at[idx, "title"] = info["title"]
        df.at[idx, "full_text"] = info["full_text"]
        df.at[idx, "image_count"] = info["image_count"]

    return df

# %% [markdown]
# ## 실행부

# %% [markdown]
# ### 검색 페이지 로드

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from urllib.parse import quote_plus

from time import sleep
import random

def encode_keyword(search_keyword: str) -> str:
    return quote_plus(search_keyword)

driver = webdriver.Chrome()

# 다중 키워드가 있으면 그걸 사용, 없으면 단일 search_keyword 사용
# if search_keywords:
#     keywords_to_run = search_keywords
# else:
#     keywords_to_run = [search_keyword]

all_results = []

# for q in keywords_to_run:
print(f"\n=== 검색 시작: {search_keyword} ===")
enc_q = encode_keyword(search_keyword)

url = (
    "https://search.naver.com/search.naver"
    "?ssc=tab.blog.all"
    "&sm=tab_opt"
    "&where=blog"
    f"&query={enc_q}"
    f"&nso=so%3Ar%2Cp%3Afrom{start_date}to{end_date}"
)

driver.get(url)

from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException

#def click_detail_if_exists(driver, timeout=2):
try:
    # "상세 검색결과 보기" 요소 탐색
    elem = driver.find_element(By.XPATH, "//a[@class='more_link' and contains(text(), '상세 검색결과 보기')]")
    elem.click()
    print("상세 검색결과 보기 클릭함")
except NoSuchElementException:
    print("상세 검색결과 보기 없음 (패스)")

# %% [markdown]
# ### 스크롤
# # 스크롤
# xp = '/html'
# review_box = driver.find_element(By.XPATH, xp)
#
# for _ in range(scroll_times):
#     driver.execute_script('arguments[0].scrollTop = arguments[0].scrollHeight', review_box)
#     sleep(random.randint(2, 3))

# %% [markdown]
# ### 본문 스크랩

# %%
# 박스 선택
forms = driver.find_elements(
    By.CSS_SELECTOR,
    'div.sds-comps-vertical-layout.sds-comps-full-layout.oIxNPKojSTvxvkjdwXVC'
)
print('박스 수 :', len(forms))

# 카드별 정보 수집
success = 0
# fail_stats = {}
for i, form in enumerate(forms, start=1):
    try:
        dic = get_content(form)
        dic["search_keyword"] = keyword   # 어떤 검색어에서 나온 결과인지 기록
        all_results.append(dic)
        success += 1
    except Exception as e:
        name = type(e).__name__
        # fail_stats[name] = fail_stats.get(name, 0) + 1
        # print(f"[{q}] 카드 {i}/{len(forms)} skip → {name}: {e}")

# print(f"[{q}] 성공: {success} / {len(forms)}")
# print(f"[{q}] 실패 통계: {fail_stats}")

# 모든 결과를 하나의 DataFrame으로
df_search = pd.DataFrame(all_results)
print("총 수집 건수:", len(df_search))


df_search['idx'] = range(len(df_search))

cols = (['search_keyword','idx']
        + [c for c in df_search.columns if c not in ['search_keyword','idx']])
df_search = df_search[cols]

df_search.head()
# Out:
# 박스 수 : 143
# 총 수집 건수: 143
#                              search_keyword  idx          writer  \
# 0  네일 "라운드" -스퀘어 -오발 -오벌 -아몬드 -스퀘어오벌 -스퀘어오발    0           데일리원스
# 1  네일 "라운드" -스퀘어 -오발 -오벌 -아몬드 -스퀘어오벌 -스퀘어오발    1              깜썰
# 2  네일 "라운드" -스퀘어 -오발 -오벌 -아몬드 -스퀘어오벌 -스퀘어오발    2  Jihoney's blog
# 3  네일 "라운드" -스퀘어 -오발 -오벌 -아몬드 -스퀘어오벌 -스퀘어오발    3  살며,사랑하며~,나누며~~
# 4  네일 "라운드" -스퀘어 -오발 -오벌 -아몬드 -스퀘어오벌 -스퀘어오발    4         "운동이야기"
#
#                               title  \
# 0     강일역 미사네일샵 추천 네일해별 러블리 리본 자석네일
# 1           베트남 다낭 마사지 추천 핑크스파 네일아트
# 2          목동역네일 티비보며 편하게 딤플네일 유지력갑
# 3  청주 강서동네일 벨르뮤청주본점 추천 손끝에서 느껴지는 차이
# 4         마곡 네일샵 추천 가을 맞이 네일은 이곳에서!
#
#                                                 text        date  \
# 0  완성된 네일은 사진보다 실물이 훨씬 예쁘고, 움직일 때마다 은은하게 결이 비쳐서 볼...  2025-11-18
# 1  다음날 라운드 끝나고 다녀온 핑크스파★ 여기도 한시장에서 도보 2분? 거리라 쇼핑하...  2025-10-10
# 2  저는 짧게, 라운드로 하는데 끝이 살짝 뾰족하게 모아지는 형태로 말씀 드렸고요. 중...  2025-10-31
# 3  투명감 있는 누드핑크 라운드 네일로 깔끔하게 :) 이번엔 너무 화려한 디자인보다는 ...  2025-10-31
# 4  11월이 되면 더 추워지기 전에 가족들과 마지막 여행을 떠나는 편인데 놀러갈때 맨손...  2025-11-14
#
#                                              link
# 0                  https://blog.naver.com/zhyewon
# 1  https://blog.naver.com/jeongwon84/224036100473
# 2                https://blog.naver.com/ssongjiyo
# 3                 https://blog.naver.com/ksmember
# 4              https://blog.naver.com/sungbok3631

# %% [markdown]
# ### 블로그 본문 + 이미지 수집

# %%
### 블로그 본문 + 이미지 수집
if IS_SAVE_IMAGES or True:   # 이미지 저장 안하더라도 본문 수집은 수행
    df_enriched = enrich_with_blog_contents(df_search)
else:
    df_enriched = df_search.copy()
# Out:
# [1/143] https://blog.naver.com/zhyewon
# [2/143] https://blog.naver.com/jeongwon84/224036100473
# [3/143] https://blog.naver.com/ssongjiyo
# [4/143] https://blog.naver.com/ksmember
# [5/143] https://blog.naver.com/sungbok3631
# [6/143] https://blog.naver.com/or____________/224065325666
# [7/143] https://blog.naver.com/uos3778
# [8/143] https://blog.naver.com/jriden
# [9/143] https://blog.naver.com/codus4592
# [10/143] https://blog.naver.com/redsea2905
# [11/143] https://blog.naver.com/arinluv/224078607261
# [12/143] https://blog.naver.com/rrsnow/224068854021
# [13/143] https://blog.naver.com/shaoren
# [14/143] https://blog.naver.com/pinkaki84
# [15/143] https://blog.naver.com/dbsgmlx
# [16/143] https://blog.naver.com/misspp78
# [17/143] https://blog.naver.com/choiseou
# [18/143] https://blog.naver.com/zhuxi-
# [19/143] https://blog.naver.com/dmswn2683
# [20/143] https://blog.naver.com/may112266
# [21/143] https://blog.naver.com/jhm9705
# [22/143] https://blog.naver.com/serabull
# [23/143] https://blog.naver.com/sumr2002
# [24/143] https://blog.naver.com/yeonlog1011
# [25/143] https://blog.naver.com/amormivida
# [26/143] https://blog.naver.com/greta0074
# [27/143] https://blog.naver.com/leh7284
# [28/143] https://blog.naver.com/yooree890
# [29/143] https://blog.naver.com/coolhotsil
# [30/143] https://blog.naver.com/p_potto
# [31/143] https://blog.naver.com/perfect_aj
# [32/143] https://blog.naver.com/liziah
# [33/143] https://blog.naver.com/bshjjang100
# [34/143] https://blog.naver.com/tnrua34/224042453569
# [35/143] https://blog.naver.com/joy3345/224081432426
# [36/143] https://blog.naver.com/chj_9171
# [37/143] https://blog.naver.com/seul__look
# [38/143] https://blog.naver.com/st1799
# [39/143] https://blog.naver.com/linebreakau
# [40/143] https://blog.naver.com/happymiy78
# [41/143] https://blog.naver.com/dancethenightawaye
# [42/143] https://blog.naver.com/jenny_log
# [43/143] https://blog.naver.com/wemmmg
# [44/143] https://blog.naver.com/nb98269/224027409675
# [45/143] https://blog.naver.com/gobbu13
# [46/143] https://blog.naver.com/fcchh7023
# [47/143] https://blog.naver.com/ttukk2
# [48/143] https://blog.naver.com/wing3527
# [49/143] https://blog.naver.com/sl7856
# [50/143] https://blog.naver.com/fairyviolet/224072045162
# [51/143] https://blog.naver.com/2125312
# [52/143] https://blog.naver.com/hayongio
# [53/143] https://blog.naver.com/zz_0_zz
# [54/143] https://blog.naver.com/travelday
# [55/143] https://blog.naver.com/windywitch
# [56/143] https://blog.naver.com/tjsghkwkals
# [57/143] https://blog.naver.com/vanessab
# [58/143] https://blog.naver.com/newze_/224058130680
# [59/143] https://blog.naver.com/vivnalee
# [60/143] https://blog.naver.com/ehdrh6
# [61/143] https://blog.naver.com/dbfksgl
# [62/143] https://blog.naver.com/j2lang
# [63/143] https://blog.naver.com/nailatti
# [64/143] https://blog.naver.com/hydestocker
# [65/143] https://blog.naver.com/ok4571
# [66/143] https://blog.naver.com/asset394
# [67/143] https://blog.naver.com/lovelyelice/224041958707
# [68/143] https://blog.naver.com/hott0116/224044771408
# [69/143] https://blog.naver.com/sailorsaturn/223970091649
# [70/143] https://blog.naver.com/ehshadow
# [71/143] https://blog.naver.com/morningstar7/223926542750
# [72/143] https://blog.naver.com/smy2166/224037464864
# [73/143] https://blog.naver.com/1004eihwa
# [74/143] https://blog.naver.com/hisuging
# [75/143] https://blog.naver.com/minipori
# [76/143] https://blog.naver.com/rhdmss0201
# [77/143] https://blog.naver.com/dony_zzang/224009326350
# [78/143] https://blog.naver.com/mina8924
# [79/143] https://blog.naver.com/aeri2884
# [80/143] https://blog.naver.com/p_yoojin
# [81/143] https://blog.naver.com/yeinmooon
# [82/143] https://blog.naver.com/choyablue
# [83/143] https://blog.naver.com/alsthwjd123
# [84/143] https://blog.naver.com/yjlovetm
# [85/143] https://blog.naver.com/loooov
# [86/143] https://blog.naver.com/hongzzang18
# [87/143] https://blog.naver.com/ch7614039
# [88/143] https://blog.naver.com/bemybela
# [89/143] https://blog.naver.com/flower2249
# [90/143] https://blog.naver.com/kminje2008
# [91/143] https://blog.naver.com/jys9018
# [92/143] https://blog.naver.com/clozetgirl
# [93/143] https://blog.naver.com/alizee8
# [94/143] https://blog.naver.com/jinnielog
# [95/143] https://blog.naver.com/dltjgua618
# [96/143] https://blog.naver.com/hbsuh1
# [97/143] https://blog.naver.com/alal7667
# [98/143] https://blog.naver.com/niney5510
# [99/143] https://blog.naver.com/jamjam0102
# [100/143] https://blog.naver.com/jsy1461
# [101/143] https://blog.naver.com/jihju261929
# [102/143] https://blog.naver.com/focl/224082778902
# [103/143] https://blog.naver.com/gshh
# [104/143] https://blog.naver.com/sso__xx
# [105/143] https://blog.naver.com/kse4966
# [106/143] https://blog.naver.com/amy171711
# [107/143] https://blog.naver.com/sy930326
# [108/143] https://blog.naver.com/review00meah
# [109/143] https://blog.naver.com/dansoonhome
# [110/143] https://blog.naver.com/0514sjsj
# [111/143] https://blog.naver.com/yi__jj
# [112/143] https://blog.naver.com/toto8664
# [113/143] https://blog.naver.com/sweetheehome
# [114/143] https://blog.naver.com/kyujini27
# [115/143] https://blog.naver.com/jungsumi21
# [116/143] https://blog.naver.com/trust_kimni
# [117/143] https://blog.naver.com/lz94kerfff
# [118/143] https://blog.naver.com/xogus2630
# [119/143] https://blog.naver.com/mari568
# [120/143] https://blog.naver.com/ryujin2919
# [121/143] https://blog.naver.com/im_yejung
# [122/143] https://blog.naver.com/didoo_ya
# [123/143] https://blog.naver.com/altnr2647
# [124/143] https://blog.naver.com/92_10_13
# [125/143] https://blog.naver.com/in_young791
# [126/143] https://blog.naver.com/miraepkkk
# [127/143] https://blog.naver.com/hijenna2
# [128/143] https://blog.naver.com/2haeun-
# [129/143] https://blog.naver.com/okc0342
# [130/143] https://blog.naver.com/gkzl67
# [131/143] https://blog.naver.com/tmxkquf2
# [132/143] https://blog.naver.com/julycoco7
# [133/143] https://blog.naver.com/luck9167
# [134/143] https://blog.naver.com/loseheart9
# [135/143] https://blog.naver.com/hyunah6734/224078147131
# [136/143] https://blog.naver.com/yeyeme
# [137/143] https://blog.naver.com/ygood_
# [138/143] https://blog.naver.com/zeongmindeulle
# [139/143] https://blog.naver.com/hyemonlogg
# [140/143] https://blog.naver.com/lobs_inside
# [141/143] https://blog.naver.com/basehappy
# [142/143] https://blog.naver.com/swih/224076295355
# [143/143] https://blog.naver.com/jmini628

# %% [markdown]
# ### CSV 저장

# %%
### CSV 저장
if IS_SAVE_CSV:
    os.makedirs(ROOT_DOWNLOAD_DIR, exist_ok=True)
    df_enriched.to_csv(CSV_PATH, index=False, encoding="utf-8-sig")
    print("CSV 저장 완료:", CSV_PATH)
# Out:
# CSV 저장 완료: craw-download-file\20251121_01_네일 추천.csv

# %%
df_enriched.head()
