# %% [markdown]
# # 네이버 검색 + 블로그 본문 스크랩

# %% [markdown]
# ## 정보 입력 / 전역 설정

# %% [markdown]
# ### 환경 변수

# %%
# 실행 순번 - 경로에 사용
RUN_INDEX = 1                 # !!중요!! - 실행=파일명 순번 => 수동 업데이트

# --- 검색 일자 ---
start_date = '20250101'
end_date = ''                 # 입력 안 하면 오늘 날짜로 세팅

# --- 스크롤 횟수 ---
scroll_times = 10              # 스크롤 횟수

# --- 다운로드 옵션 ---
IS_SAVE_CSV = True            # CSV(엑셀용) 저장 여부
IS_SAVE_IMAGES = False         # 이미지 저장 여부

# --- 파일 다운로드 경로 (ROOT) --
ROOT_DOWNLOAD_DIR = 'craw-download-file'

# %% [markdown]
# ### 검색 키워드 입력

# %%
# 단일 키워드
keyword = '네일추천'            # 검색 키워드
search_keyword = keyword      # 검색창에 넣을 실제 값

# 다중 키워드 (여러번 검색 수행) - 비어 있다면, 단일 키워드로 수행
search_keywords = [
    # 1) 기본/일반 네일 (베이스 분포용)
    "네일 추천",
    "네일 디자인",
    "셀프네일 디자인",
    "데일리 네일",
    "직장인 네일",

    # # 2) 쉐입 중심
    # "라운드 네일 디자인",
    # "오벌 네일 디자인",
    # "스퀘어 네일 디자인",
    # "스퀘어오벌 네일",
    # "아몬드 네일 디자인",

    # # 3) 길이·손 특징 중심
    # "짧은 손톱 네일",
    # "짧은손톱 셀프네일",
    # "긴 손톱 네일",
    # "손가락 길어보이는 네일",
    # "손이 예뻐보이는 네일",
]

# %% [markdown]
# ## 함수 정의

# %% [markdown]
# ### 모듈 import

# %%
import os
import re
import requests
from datetime import datetime
from urllib.parse import urljoin

import pandas as pd
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
import mimetypes

# %% [markdown]
# ### 파일 경로

# %%
## 파일 경로 : 일자 + 실행 순번 + 검색어 or multi

today_date = datetime.now().strftime("%Y%m%d")

def sanitize_keyword(kw: str) -> str:
    """파일/폴더명으로 쓸 수 있게 키워드 정제 """
    if not isinstance(kw, str):
        kw = str(kw)
    kw = kw.strip().strip('"').strip("'")
    # 파일명에 쓸 수 없는 문자 제거
    kw = re.sub(r'[\\/:*?"<>|]', '_', kw)
    # 너무 길면 잘라내기
    if len(kw) == 0:
        kw = "keyword"
    return kw

### 단일/다중에 따라 파일명 기준 키워드 결정
if search_keywords:          # 다중 키워드 리스트가 비어있지 않다면
    base_keyword_for_path = "multi"
else:
    base_keyword_for_path = search_keyword

SAFE_KEYWORD = sanitize_keyword(base_keyword_for_path)

SUB_NAME = f"{today_date}_{RUN_INDEX:02d}_{SAFE_KEYWORD}"

CSV_PATH = os.path.join(ROOT_DOWNLOAD_DIR, f"{SUB_NAME}.csv")
IMAGE_DIR = os.path.join(ROOT_DOWNLOAD_DIR, SUB_NAME)

# %% [markdown]
# ### 날짜 정규화

# %%
import re
from datetime import datetime, timedelta, timezone

KST = timezone(timedelta(hours=9))

_abs = re.compile(r"^\s*(\d{4})\.(\d{1,2})\.(\d{1,2})\.?\s*$")
_m  = re.compile(r"(\d+)\s*분\s*전")
_h  = re.compile(r"(\d+)\s*시간\s*전")
_d  = re.compile(r"(\d+)\s*일\s*전")
_w  = re.compile(r"(\d+)\s*주\s*전")
_not_date_tail = re.compile(r"(?:단|TOP),\s*$")        # 예: "A34면 1단," , "A30면 TOP,"

def _ymd(dt: datetime) -> str:
    # Python/Excel 공통 인식 포맷: YYYY-MM-DD
    return f"{dt.year:04d}-{dt.month:02d}-{dt.day:02d}"

def normalize_news_date(texts, now: datetime | None = None) -> str | None:
    # 변환 실패 대비: 원본 첫 값 보관
    original_first = texts if isinstance(texts, str) else (texts[0] if texts else None)

    if isinstance(texts, str):
        texts = [texts]
    now = now or datetime.now(KST)

    for t in texts:
        if not t:
            continue
        s = t.strip()

        # 지면/면·단, TOP 꼬리면 스킵
        if _not_date_tail.search(s):
            continue

        # 절대형
        m = _abs.match(s)
        if m:
            y, mo, d = map(int, m.groups())
            return f"{y:04d}-{mo:02d}-{d:02d}"

        # 상대형
        if (mm := _h.search(s)): # 분
            return _ymd(now - timedelta(minutes=int(mm.group(1))))
        if (mh := _h.search(s)): # 시간
            return _ymd(now - timedelta(hours=int(mh.group(1))))
        if (md := _d.search(s)): # 일
            return _ymd(now - timedelta(days=int(md.group(1))))
        if (mw := _w.search(s)): # 주
            return _ymd(now - timedelta(weeks=int(mw.group(1))))

    # 날짜형 변환이 안되면 첫 번째 값 반환
    return original_first

# %% [markdown]
# ### 검색 결과 카드 한 개에서 정보 추출

# %%
def get_content(review):
    condic = {}

    title_css  = (
        "span.sds-comps-text.sds-comps-text-ellipsis.sds-comps-text-ellipsis-1"
        ".sds-comps-text-type-headline1.sds-comps-text-weight-sm"
    )
    text_css   = (
        "span.sds-comps-text-type-body1"
    )
    viewer_css = (
        "div.sds-comps-horizontal-layout.sds-comps-inline-layout"
        ".sds-comps-profile-info-title"
    )
    date_css   = (
        "span.sds-comps-text.sds-comps-text-type-body2"
        ".sds-comps-text-weight-sm.sds-comps-profile-info-subtext"
    )
    link_css   = 'a[href*="blog.naver.com"]'

    condic['writer'] = review.find_element(By.CSS_SELECTOR, viewer_css) \
                             .get_attribute('innerText').strip()
    condic['title'] = review.find_element(By.CSS_SELECTOR, title_css) \
                             .get_attribute('innerText').strip()
    condic['text'] = review.find_element(By.CSS_SELECTOR, text_css) \
                            .get_attribute('innerText').strip()
    condic['date'] = normalize_news_date(
        review.find_element(By.CSS_SELECTOR, date_css)
              .get_attribute('innerText').strip()
    )
    try:
        condic['link'] = review.find_element(By.CSS_SELECTOR, link_css) \
                                .get_attribute('href')
    except Exception:
        condic['link'] = ''
        print(f"condic['link'] -> 추출오류 : {condic['title']}")

    return condic

# %% [markdown]
# ### 블로그 본문 크롤링 + 이미지 저장

# %%
def crawl_blog_content(url: str, search_idx: int,
                       image_dir: str,
                       is_download_images: bool = True):

    COMMON_HEADERS = {"User-Agent": "Mozilla/5.0"}

    resp = requests.get(url, headers=COMMON_HEADERS)
    resp.raise_for_status()
    soup = BeautifulSoup(resp.text, "html.parser")

    # iframe 찾기
    iframe = soup.select_one("iframe#mainFrame")
    if iframe is None:
        for f in soup.find_all("iframe"):
            src = f.get("src") or ""
            if "PostView" in src:
                iframe = f
                break

    if iframe is None:
        print(f"[WARN] iframe 없음 → {url}")
        return {"title": "", "full_text": "", "image_count": 0}

    inner_src = iframe.get("src")
    inner_url = urljoin(resp.url, inner_src)

    # iframe 안쪽 요청
    resp2 = requests.get(inner_url, headers=COMMON_HEADERS)
    resp2.raise_for_status()
    soup2 = BeautifulSoup(resp2.text, "html.parser")

    # 제목
    title_tag = soup2.find("title")
    title = title_tag.get_text(strip=True) if title_tag else ""

    # 본문 텍스트
    paragraphs = [p.get_text(" ", strip=True) for p in soup2.find_all("p")]
    full_text = "\n".join(paragraphs)

    if not full_text.strip():
        main_div = soup2.select_one("div.se-main-container")
        if main_div:
            paragraphs = [
                p.get_text(" ", strip=True)
                for p in main_div.find_all(["p", "span"])
            ]
            full_text = "\n".join(paragraphs)

    # 이미지 다운로드
    image_count = 0
    if is_download_images:
        content = (
            soup2.select_one("div.se-main-container")
            or soup2.select_one("#postViewArea")
            or soup2
        )
        img_tags = content.find_all("img")

        os.makedirs(image_dir, exist_ok=True)

        allowed_hosts = ("postfiles.pstatic.net", "blogfiles.pstatic.net")

        for img_idx, img in enumerate(img_tags, start=1):
            src = img.get("data-origin") or img.get("data-src") or img.get("src")
            if not src:
                continue

            if not any(h in src for h in allowed_hosts):
                continue

            if src.startswith("//"):
                src = "https:" + src
            elif src.startswith("/"):
                src = urljoin(inner_url, src)
            if src.startswith("data:"):
                continue

            hi_src = src
            if "type=w80_blur" in src:
                hi_src = src.replace("type=w80_blur", "type=w966")

            img_headers = {
                "User-Agent": "Mozilla/5.0",
                "Referer": inner_url,
            }

            img_resp = None
            for candidate in [hi_src, src]:
                try:
                    r = requests.get(candidate, headers=img_headers, timeout=10)
                    r.raise_for_status()
                    img_resp = r
                    break
                except Exception:
                    img_resp = None

            if img_resp is None:
                continue

            content_type = img_resp.headers.get("Content-Type", "")
            if "image" not in content_type:
                continue

            if not is_download_images:
                image_count += 1
                continue

            ext = mimetypes.guess_extension(content_type.split(";")[0]) or ".jpg"

            # IMG_{검색결과순번 4자리}_{본문내 이미지순번 4자리}
            filename = os.path.join(
                image_dir,
                f"IMG_{search_idx:04d}_{img_idx:04d}{ext}"
            )

            with open(filename, "wb") as f:
                f.write(img_resp.content)

            image_count += 1

    return {
        "title": title,
        "full_text": full_text,
        "image_count": image_count,
    }


def enrich_with_blog_contents(df_search: pd.DataFrame) -> pd.DataFrame:
    """
    1번 검색 df 기준:
    - title 덮어쓰기 (블로그 실제 제목)
    - full_text 열 추가
    - image_count 열 추가
    """

    df = df_search.copy()
    df["full_text"] = ""
    df["image_count"] = 0

    for idx, row in df.iterrows():
        url = row.get("link", "")
        if not isinstance(url, str) or not url.strip():
            continue

        search_idx = idx + 1
        print(f"[{search_idx}/{len(df)}] {url}")

        info = crawl_blog_content(
            url=url,
            search_idx=search_idx,
            image_dir=IMAGE_DIR,
            is_download_images=IS_SAVE_IMAGES
        )

        df.at[idx, "title"] = info["title"]
        df.at[idx, "full_text"] = info["full_text"]
        df.at[idx, "image_count"] = info["image_count"]

    return df

# %% [markdown]
# ## 실행부

# %% [markdown]
# ### 검색 페이지 로드 / 스크롤 / 본문 스크랩

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from urllib.parse import quote_plus

from time import sleep
import random

def encode_keyword(search_keyword: str) -> str:
    return quote_plus(search_keyword)

driver = webdriver.Chrome()

# 다중 키워드가 있으면 그걸 사용, 없으면 단일 search_keyword 사용
if search_keywords:
    keywords_to_run = search_keywords
else:
    keywords_to_run = [search_keyword]

all_results = []

for q in keywords_to_run:
    print(f"\n=== 검색 시작: {q} ===")
    enc_q = encode_keyword(q)

    url = (
        "https://search.naver.com/search.naver"
        "?ssc=tab.blog.all"
        "&sm=tab_opt"
        "&where=blog"
        f"&query={enc_q}"
        f"&nso=so%3Ar%2Cp%3Afrom{start_date}to{end_date}"
    )

    driver.get(url)

    # 스크롤
    xp = '/html'
    review_box = driver.find_element(By.XPATH, xp)

    for _ in range(scroll_times):
        driver.execute_script('arguments[0].scrollTop = arguments[0].scrollHeight', review_box)
        sleep(random.randint(2, 3))

    # 박스 선택
    forms = driver.find_elements(
        By.CSS_SELECTOR,
        'div.sds-comps-vertical-layout.sds-comps-full-layout.YNThgbNOBFUb3Wc2Cq47'
    )
    print('박스 수 :', len(forms))

    # 카드별 정보 수집
    success = 0
    # fail_stats = {}
    for i, form in enumerate(forms, start=1):
        try:
            dic = get_content(form)
            dic["search_keyword"] = q   # 어떤 검색어에서 나온 결과인지 기록
            all_results.append(dic)
            success += 1
        except Exception as e:
            name = type(e).__name__
            # fail_stats[name] = fail_stats.get(name, 0) + 1
            # print(f"[{q}] 카드 {i}/{len(forms)} skip → {name}: {e}")

    # print(f"[{q}] 성공: {success} / {len(forms)}")
    # print(f"[{q}] 실패 통계: {fail_stats}")

# 모든 결과를 하나의 DataFrame으로
df_search = pd.DataFrame(all_results)
print("총 수집 건수:", len(df_search))


df_search['idx'] = range(len(df_search))

cols = (['idx', 'search_keyword']
        + [c for c in df_search.columns if c not in ['idx', 'search_keyword']])
df_search = df_search[cols]

df_search.head()
# Out:
# === 검색 시작: 네일 추천 ===
# 박스 수 : 126
# condic['link'] -> 추출오류 : 네일아트하러 서울에서 방문하는 손더네일
#
# === 검색 시작: 네일 디자인 ===
# 박스 수 : 94
# condic['link'] -> 추출오류 : 네일아트 자격증 필기 실기에 대해서
#
# === 검색 시작: 셀프네일 디자인 ===
# 박스 수 : 110
#
# === 검색 시작: 데일리 네일 ===
# 박스 수 : 128
#
# === 검색 시작: 직장인 네일 ===
# 박스 수 : 137
# 총 수집 건수: 595
#    idx search_keyword             writer                               title  \
# 0    0          네일 추천                 깜썰             베트남 다낭 마사지 추천 핑크스파 네일아트
# 1    1          네일 추천    쥔이로그 : 뷰티&패션&팝업    자석젤 다이소 네일팁 웨딩네일 추천, 간단하게 포인트 주기
# 2    2          네일 추천       ★ 빛나는 나의 길 ★           경성대 부경대네일 랑만뷰티살롱 쿠로미네일 추천
# 3    3          네일 추천  뉴라와 구름이의 먹방 라이프⭐️  범계 속눈썹 연장 잘하는 벨라네일 추천 (주차, 애견동반가능)
# 4    4          네일 추천              [생각중]          강남 선릉역네일 화려한네일 전문샵 도쿄네일 추천
#
#                                                 text        date  \
# 0  베트남 다낭 마사지 추천 핑크스파 네일아트 하잉, 여행블로거 깜썰입니다 :) 남편 ...  2025-10-10
# 1  "자석젤 다이소 네일팁 웨딩네일 추천, 간단하게 포인트 주기" 안녕하세요! 쥔이입니...  2025-08-17
# 2  [ 경성대 부경대네일 랑만뷰티살롱 ] 쿠로미네일 추천 쿠로미 좋아하는 사람들 다 모...  2025-11-06
# 3  안녕하세요 뉴릉이입니다~ 저는 이번에 새로운 연장 잘 하는 곳을 찾다가 범계 속눈썹...  2025-11-17
# 4  규모가 크고 인테리어도 멋지면서 편안하게 네일을 받을 수 있는 강남 선릉역네일 화려...  2025-10-30
#
#                                              link
# 0  https://blog.naver.com/jeongwon84/224036100473
# 1                  https://blog.naver.com/486xhxh
# 2                  https://blog.naver.com/wonnabe
# 3                  https://blog.naver.com/our0511
# 4                  https://blog.naver.com/molly32

# %% [markdown]
# ### 블로그 본문 + 이미지 수집

# %%
### 블로그 본문 + 이미지 수집
if IS_SAVE_IMAGES or True:   # 이미지 저장 안하더라도 본문 수집은 수행
    df_enriched = enrich_with_blog_contents(df_search)
else:
    df_enriched = df_search.copy()
# Out:
# [1/595] https://blog.naver.com/jeongwon84/224036100473
# [2/595] https://blog.naver.com/486xhxh
# [3/595] https://blog.naver.com/wonnabe
# [4/595] https://blog.naver.com/our0511
# [5/595] https://blog.naver.com/molly32
# [6/595] https://blog.naver.com/heoyumi94
# [7/595] https://blog.naver.com/darkyoon85/224075245164
# [8/595] https://blog.naver.com/hw03088
# [9/595] https://blog.naver.com/tjdbs0323/224077123725
# [10/595] https://blog.naver.com/aprilsong19/224045784654
# [12/595] https://blog.naver.com/sunkjydbgn/224079739219
# [13/595] https://blog.naver.com/wh110595
# [14/595] https://blog.naver.com/idb0704
# [15/595] https://blog.naver.com/sbnita_bibi
# [16/595] https://blog.naver.com/abalico
# [17/595] https://blog.naver.com/hwang_c11
# [18/595] https://blog.naver.com/k_fla
# [19/595] https://blog.naver.com/diecruel/224030153990
# [20/595] https://blog.naver.com/ggggggenie/224063015455
# [21/595] https://blog.naver.com/banglang93
# [22/595] https://blog.naver.com/sscd0808/224068978485
# [23/595] https://blog.naver.com/gmj0117
# [24/595] https://blog.naver.com/elog__
# [25/595] https://blog.naver.com/jjun2989
# [26/595] https://blog.naver.com/leyejin486
# [27/595] https://blog.naver.com/bongbong323
# [28/595] https://blog.naver.com/smilehh406
# [29/595] https://blog.naver.com/danwoo47jh/224059529028
# [30/595] https://blog.naver.com/viviankk
# [31/595] https://blog.naver.com/huhumami
# [32/595] https://blog.naver.com/ryuel5
# [33/595] https://blog.naver.com/nailatti
# [34/595] https://blog.naver.com/jiyea_junjin
# [35/595] https://blog.naver.com/milbeauty/224059646609
# [36/595] https://blog.naver.com/goodse7/224079269407
# [37/595] https://blog.naver.com/hearteffect/224002756496
# [38/595] https://blog.naver.com/seulillililiiiilill
# [39/595] https://blog.naver.com/nsound1226
# [40/595] https://blog.naver.com/yehaco/224078996165
# [41/595] https://blog.naver.com/hydestocker
# [42/595] https://blog.naver.com/minidebebe
# [43/595] https://blog.naver.com/dms4613
# [44/595] https://blog.naver.com/jetchoi
# [45/595] https://blog.naver.com/freerull7
# [46/595] https://blog.naver.com/youridalbit/224078640965
# [47/595] https://blog.naver.com/s_eun2/224076932921
# [48/595] https://blog.naver.com/zonever7
# [49/595] https://blog.naver.com/zixnee
# [50/595] https://blog.naver.com/juvide
# [51/595] https://blog.naver.com/hloveh01/224072856229
# [52/595] https://blog.naver.com/mjydestiny/224028713982
# [53/595] https://blog.naver.com/pingk0905
# [54/595] https://blog.naver.com/h5tcjstk
# [55/595] https://blog.naver.com/lifeisswell
# [56/595] https://blog.naver.com/lindaintheworld
# [57/595] https://blog.naver.com/p_yoojin
# [58/595] https://blog.naver.com/hyetu_
# [59/595] https://blog.naver.com/yeonlog1011
# [60/595] https://blog.naver.com/sunnyjung448
# [61/595] https://blog.naver.com/jjumi1020
# [62/595] https://blog.naver.com/aboutcheny
# [63/595] https://blog.naver.com/nonovely
# [64/595] https://blog.naver.com/lsbangel
# [65/595] https://blog.naver.com/liziah
# [66/595] https://blog.naver.com/az8607
# [67/595] https://blog.naver.com/har0913
# [68/595] https://blog.naver.com/jinhii88
# [69/595] https://blog.naver.com/xhxhdhkalvl/224014691444
# [70/595] https://blog.naver.com/milkcreamcheese_
# [71/595] https://blog.naver.com/sugar9976/224035029925
# [72/595] https://blog.naver.com/rrsnow/224044996675
# [73/595] https://blog.naver.com/iamdaze__/224055864853
# [74/595] https://blog.naver.com/natahlie
# [75/595] https://blog.naver.com/minsu2-
# [76/595] https://blog.naver.com/janek0105
# [77/595] https://blog.naver.com/tyg04131
# [78/595] https://blog.naver.com/beautyquokka
# [79/595] https://blog.naver.com/rouge219
# [80/595] https://blog.naver.com/limessung
# [81/595] https://blog.naver.com/chldmsal22
# [82/595] https://blog.naver.com/angle8725
# [83/595] https://blog.naver.com/hajw0129
# [84/595] https://blog.naver.com/jsjjsj8
# [85/595] https://blog.naver.com/dadaland9
# [86/595] https://blog.naver.com/heexee
# [87/595] https://blog.naver.com/layeonparkgogo/224072677950
# [88/595] https://blog.naver.com/lovedarl2/224078457831
# [89/595] https://blog.naver.com/baechu_tv
# [90/595] https://blog.naver.com/happymasami
# [91/595] https://blog.naver.com/sssord12/224058062883
# [92/595] https://blog.naver.com/lsm991227
# [93/595] https://blog.naver.com/godud10
# [94/595] https://blog.naver.com/bigbang3527
# [95/595] https://blog.naver.com/dole222/224043461946
# [96/595] https://blog.naver.com/munsun1513
# [97/595] https://blog.naver.com/yeonimood_
# [98/595] https://blog.naver.com/lxxhxxming
# [99/595] https://blog.naver.com/siunim/224067008930
# [100/595] https://blog.naver.com/starlike_zz/224078021194
# [101/595] https://blog.naver.com/gjf10-14
# [102/595] https://blog.naver.com/tlstpdus55
# [103/595] https://blog.naver.com/miso2130
# [104/595] https://blog.naver.com/qufqlc08/224080111262
# [105/595] https://blog.naver.com/hjrang0606/224067002975
# [106/595] https://blog.naver.com/soyeong0407
# [107/595] https://blog.naver.com/mangonoonim
# [108/595] https://blog.naver.com/tbzm32
# [109/595] https://blog.naver.com/di_bbo/224037308818
# [110/595] https://blog.naver.com/noniz
# [111/595] https://blog.naver.com/wldms7203
# [112/595] https://blog.naver.com/jinjoo0426
# [113/595] https://blog.naver.com/jjyoon6228
# [114/595] https://blog.naver.com/052young
# [115/595] https://blog.naver.com/cinnamon0412/224069110416
# [116/595] https://blog.naver.com/cjfng
# [117/595] https://blog.naver.com/tsp011660
# [118/595] https://blog.naver.com/rlathddl8651
# [119/595] https://blog.naver.com/h_hji/224066885303
# [120/595] https://blog.naver.com/kwonhs1003
# [121/595] https://blog.naver.com/dbwlsdk0813
# [122/595] https://blog.naver.com/myung920612
# [123/595] https://blog.naver.com/33333jh
# [124/595] https://blog.naver.com/leah2401
# [125/595] https://blog.naver.com/haeuni9196
# [126/595] https://blog.naver.com/92_10_13
# [127/595] https://blog.naver.com/tjdbs0323/224071506506
# [128/595] https://blog.naver.com/or____________/224016647906
# [129/595] https://blog.naver.com/pm3439
# [130/595] https://blog.naver.com/argentline
# [131/595] https://blog.naver.com/lqud/224025181574
# [132/595] https://blog.naver.com/jetchoi
# [133/595] https://blog.naver.com/blackholecd/224039203093
# [134/595] https://blog.naver.com/miniminimin__
# [135/595] https://blog.naver.com/leyejin486
# [136/595] https://blog.naver.com/5pen_room617/224072679629
# [138/595] https://blog.naver.com/1hello2/224072803343
# [139/595] https://blog.naver.com/hydestocker
# [140/595] https://blog.naver.com/ys_yg_/224075338378
# [141/595] https://blog.naver.com/farbemaria/224049545428
# [142/595] https://blog.naver.com/freerull7
# [143/595] https://blog.naver.com/holareina
# [144/595] https://blog.naver.com/sugar9976/224035029925
# [145/595] https://blog.naver.com/la_chun
# [146/595] https://blog.naver.com/ians211/224073338415
# [147/595] https://blog.naver.com/viviankk
# [148/595] https://blog.naver.com/hearteffect/224031023012
# [149/595] https://blog.naver.com/mythya0730/224036018245
# [150/595] https://blog.naver.com/jiyea_junjin
# [151/595] https://blog.naver.com/nagi96/224047204051
# [152/595] https://blog.naver.com/youridalbit/224062028456
# [153/595] https://blog.naver.com/goodse7/224031852779
# [154/595] https://blog.naver.com/yhm4082/224081520496
# [155/595] https://blog.naver.com/sunkjydbgn/224001383535
# [156/595] https://blog.naver.com/bambi_showpu/224015484088
# [157/595] https://blog.naver.com/mjydestiny/224028713982
# [158/595] https://blog.naver.com/iamdaze__/224055864853
# [159/595] https://blog.naver.com/qkrdmsdhr95/223934878650
# [160/595] https://blog.naver.com/aboutcheny
# [161/595] https://blog.naver.com/ryuel5
# [162/595] https://blog.naver.com/chois909/224081066778
# [163/595] https://blog.naver.com/masung_xoxo/224055903830
# [164/595] https://blog.naver.com/borareview/224077170125
# [165/595] https://blog.naver.com/a1070bbb
# [166/595] https://blog.naver.com/har0913
# [167/595] https://blog.naver.com/doublesholdings/224076114174
# [168/595] https://blog.naver.com/s_eun2/224076932921
# [169/595] https://blog.naver.com/minimouse24/223977465991
# [170/595] https://blog.naver.com/flutistpark
# [171/595] https://blog.naver.com/euni4441/224016742462
# [172/595] https://blog.naver.com/f2mg1
# [173/595] https://blog.naver.com/m_a_u_
# [174/595] https://blog.naver.com/minjihi89
# [175/595] https://blog.naver.com/liziah
# [176/595] https://blog.naver.com/bbekimha/224020083005
# [177/595] https://blog.naver.com/b1758/224003463732
# [178/595] https://blog.naver.com/bintorynim/224070273212
# [179/595] https://blog.naver.com/banggeul07/224064301442
# [180/595] https://blog.naver.com/qufqlc08/224080111262
# [181/595] https://blog.naver.com/free_beauty_/224075178455
# [182/595] https://blog.naver.com/layeonparkgogo/224078163435
# [183/595] https://blog.naver.com/johappy1128
# [184/595] https://blog.naver.com/momentofmiracle1017/224067341931
# [185/595] https://blog.naver.com/bbodae0329
# [186/595] https://blog.naver.com/sssord12/224076876034
# [187/595] https://blog.naver.com/princessminha/224050406996
# [188/595] https://blog.naver.com/jsjjsj8
# [189/595] https://blog.naver.com/mu_cogi
# [190/595] https://blog.naver.com/lsm991227
# [191/595] https://blog.naver.com/hnluv1004
# [192/595] https://blog.naver.com/dole222/224043461946
# [193/595] https://blog.naver.com/jsh9353
# [194/595] https://blog.naver.com/lxxhxxming
# [195/595] https://blog.naver.com/yoni_0905/224025890185
# [196/595] https://blog.naver.com/njuiwwik/224044830826
# [197/595] https://blog.naver.com/sy01598/224030260591
# [198/595] https://blog.naver.com/so0ho2/224035704219
# [199/595] https://blog.naver.com/lovedarl2/224076778708
# [200/595] https://blog.naver.com/tlstpdus55
# [201/595] https://blog.naver.com/yoojinjeong/224078680281
# [202/595] https://blog.naver.com/mhhj951026/224076140649
# [203/595] https://blog.naver.com/soyosoyo01/224079826102
# [204/595] https://blog.naver.com/checkmate_out
# [205/595] https://blog.naver.com/khsshinhwa
# [206/595] https://blog.naver.com/starlike_zz/224064850419
# [207/595] https://blog.naver.com/areum__ing
# [208/595] https://blog.naver.com/ccccccho_v/224070389937
# [209/595] https://blog.naver.com/withtyche_
# [210/595] https://blog.naver.com/soll_beauty/224075172253
# [211/595] https://blog.naver.com/2uni_/224066953221
# [212/595] https://blog.naver.com/hi_sat
# [213/595] https://blog.naver.com/kdseul33
# [214/595] https://blog.naver.com/seul_gei
# [215/595] https://blog.naver.com/92_10_13
# [216/595] https://blog.naver.com/levely3294/224035216326
# [217/595] https://blog.naver.com/jej2821
# [218/595] https://blog.naver.com/kwonhs1003
# [219/595] https://blog.naver.com/052young
# [220/595] https://blog.naver.com/ekgp1356
# [221/595] https://blog.naver.com/tjdbs0323/224077123725
# [222/595] https://blog.naver.com/ians211/223934634119
# [223/595] https://blog.naver.com/hearteffect/223947260340
# [224/595] https://blog.naver.com/rrsnow/223860717277
# [225/595] https://blog.naver.com/thumbnail2021
# [226/595] https://blog.naver.com/youridalbit/223947781939
# [227/595] https://blog.naver.com/mythya0730/223832941762
# [228/595] https://blog.naver.com/goodse7/224043603106
# [229/595] https://blog.naver.com/llllbej
# [230/595] https://blog.naver.com/hyeon_dyu
# [231/595] https://blog.naver.com/danwoo47jh/223810591127
# [232/595] https://blog.naver.com/shamihaeun
# [233/595] https://blog.naver.com/bbekimha/223794517853
# [234/595] https://blog.naver.com/zzeroee
# [235/595] https://blog.naver.com/chois909/223928309466
# [236/595] https://blog.naver.com/howzu/223895401701
# [237/595] https://blog.naver.com/jungeun9019/224069433927
# [238/595] https://blog.naver.com/free_beauty_/223931430940
# [239/595] https://blog.naver.com/njjung0565/223595543146
# [240/595] https://blog.naver.com/andoo7/223844881313
# [241/595] https://blog.naver.com/unidus37
# [242/595] https://blog.naver.com/suomi375
# [243/595] https://blog.naver.com/cw1955
# [244/595] https://blog.naver.com/aobo7
# [245/595] https://blog.naver.com/4chi_27
# [246/595] https://blog.naver.com/minimouse24/223494716611
# [247/595] https://blog.naver.com/conpjs_91/224005463981
# [248/595] https://blog.naver.com/sugar9976/223581742125
# [249/595] https://blog.naver.com/seoyan11/224040898994
# [250/595] https://blog.naver.com/mouse1234567
# [251/595] https://blog.naver.com/n7a9a0hb
# [252/595] https://blog.naver.com/jyogei
# [253/595] https://blog.naver.com/attractive202584_
# [254/595] https://blog.naver.com/e_h95
# [255/595] https://blog.naver.com/lovedarl2/223985769700
# [256/595] https://blog.naver.com/dbdutk1313/224074860596
# [257/595] https://blog.naver.com/tg021912
# [258/595] https://blog.naver.com/hellodany_/223871024829
# [259/595] https://blog.naver.com/hansol_28
# [260/595] https://blog.naver.com/eqx83276
# [261/595] https://blog.naver.com/roa_1229
# [262/595] https://blog.naver.com/2un4wrgr
# [263/595] https://blog.naver.com/odry_lily/224068982296
# [264/595] https://blog.naver.com/wb04dj4b
# [265/595] https://blog.naver.com/miyustory/223849700429
# [266/595] https://blog.naver.com/jooyun0615
# [267/595] https://blog.naver.com/56u3cif6
# [268/595] https://blog.naver.com/theoidjtrio
# [269/595] https://blog.naver.com/ji8unofa
# [270/595] https://blog.naver.com/jfuihbusvbj
# [271/595] https://blog.naver.com/hyehye127
# [272/595] https://blog.naver.com/dongdongza79/224000413738
# [273/595] https://blog.naver.com/sfyrzf93602
# [274/595] https://blog.naver.com/fool77x/224005870246
# [275/595] https://blog.naver.com/honey-rin/224027457904
# [276/595] https://blog.naver.com/bchr523
# [277/595] https://blog.naver.com/jiyouth_
# [278/595] https://blog.naver.com/ohj809
# [279/595] https://blog.naver.com/sgy0325
# [280/595] https://blog.naver.com/alodia22/223767222636
# [281/595] https://blog.naver.com/mmins-0610/224006613419
# [282/595] https://blog.naver.com/nbc9896/223834909182
# [283/595] https://blog.naver.com/nail_chowon
# [284/595] https://blog.naver.com/so0ho2/223957657852
# [285/595] https://blog.naver.com/wjkdprfmh
# [286/595] https://blog.naver.com/lwgf6771
# [287/595] https://blog.naver.com/pepekjin/224037058950
# [288/595] https://blog.naver.com/u_sunny95
# [289/595] https://blog.naver.com/bora900109
# [290/595] https://blog.naver.com/wise202691_
# [291/595] https://blog.naver.com/aquarius8588/223766035462
# [292/595] https://blog.naver.com/kdseul33
# [293/595] https://blog.naver.com/itsjbrows2
# [294/595] https://blog.naver.com/ghnst
# [295/595] https://blog.naver.com/rgir5591
# [296/595] https://blog.naver.com/zzangha_11/224030720684
# [297/595] https://blog.naver.com/covlr486
# [298/595] https://blog.naver.com/lsibmwta
# [299/595] https://blog.naver.com/hidbct8849
# [300/595] https://blog.naver.com/e4xbg51h
# [301/595] https://blog.naver.com/xti4selh
# [302/595] https://blog.naver.com/iteiscects916
# [303/595] https://blog.naver.com/najwurgpm
# [304/595] https://blog.naver.com/elegiee
# [305/595] https://blog.naver.com/kindfriendsss21273
# [306/595] https://blog.naver.com/kdac4131
# [307/595] https://blog.naver.com/x1prejvf
# [308/595] https://blog.naver.com/bvjunchlk
# [309/595] https://blog.naver.com/ddoggooming
# [310/595] https://blog.naver.com/dorothy2578/223997030098
# [311/595] https://blog.naver.com/sqsjlbznr
# [312/595] https://blog.naver.com/tempter1004
# [313/595] https://blog.naver.com/happygo1036
# [314/595] https://blog.naver.com/5cl5voak
# [315/595] https://blog.naver.com/mm03w2rt
# [316/595] https://blog.naver.com/zsqtwywks
# [317/595] https://blog.naver.com/engaging202702_
# [318/595] https://blog.naver.com/f9sq6d3w
# [319/595] https://blog.naver.com/sterism73775
# [320/595] https://blog.naver.com/sweetbeau1179
# [321/595] https://blog.naver.com/f87cu6a9
# [322/595] https://blog.naver.com/gbon123
# [323/595] https://blog.naver.com/4jua8kcq
# [324/595] https://blog.naver.com/6cs2bpc8
# [325/595] https://blog.naver.com/tdvnfkmp
# [326/595] https://blog.naver.com/3gnr5np5
# [327/595] https://blog.naver.com/krx3802jqi
# [328/595] https://blog.naver.com/sunnysmiles11205
# [329/595] https://blog.naver.com/joshua200814
# [330/595] https://blog.naver.com/gvrbylzlh
# [331/595] https://blog.naver.com/leyejin486
# [332/595] https://blog.naver.com/danwoo47jh/224048656533
# [333/595] https://blog.naver.com/yjn1221/223890005152
# [334/595] https://blog.naver.com/kdseul33
# [335/595] https://blog.naver.com/nailatti
# [336/595] https://blog.naver.com/mythya0730/223894924086
# [337/595] https://blog.naver.com/springmincos
# [338/595] https://blog.naver.com/har0913
# [339/595] https://blog.naver.com/zzzo4ozzz
# [340/595] https://blog.naver.com/seulsel_
# [341/595] https://blog.naver.com/wjuzi
# [342/595] https://blog.naver.com/qnpfrhh3
# [343/595] https://blog.naver.com/sscd0808/223851964353
# [344/595] https://blog.naver.com/nametel
# [345/595] https://blog.naver.com/catwitch23/223914835125
# [346/595] https://blog.naver.com/bandinhouse_munjeong
# [347/595] https://blog.naver.com/hhoney0824
# [348/595] https://blog.naver.com/njjung0565/223910043947
# [349/595] https://blog.naver.com/arine_story
# [350/595] https://blog.naver.com/052young
# [351/595] https://blog.naver.com/bebrightyou
# [352/595] https://blog.naver.com/xhxhdhkalvl/223477288357
# [353/595] https://blog.naver.com/yang8401
# [354/595] https://blog.naver.com/pej8581
# [355/595] https://blog.naver.com/zzangrose_
# [356/595] https://blog.naver.com/khj920317
# [357/595] https://blog.naver.com/lsbangel
# [358/595] https://blog.naver.com/thesaranail/223725313577
# [359/595] https://blog.naver.com/lookatminong/223441359008
# [360/595] https://blog.naver.com/onych_oui
# [361/595] https://blog.naver.com/7sujinpark
# [362/595] https://blog.naver.com/geeyeonl
# [363/595] https://blog.naver.com/xowls4613
# [364/595] https://blog.naver.com/gabin526
# [365/595] https://blog.naver.com/gksk5172
# [366/595] https://blog.naver.com/qufqlc08/224011267597
# [367/595] https://blog.naver.com/ssenidays
# [368/595] https://blog.naver.com/afvsz
# [369/595] https://blog.naver.com/mjtm
# [370/595] https://blog.naver.com/acid_chou
# [371/595] https://blog.naver.com/house6298
# [372/595] https://blog.naver.com/johappy1128
# [373/595] https://blog.naver.com/goeyom
# [374/595] https://blog.naver.com/tg8432
# [375/595] https://blog.naver.com/miraangel2
# [376/595] https://blog.naver.com/euwoss
# [377/595] https://blog.naver.com/janek0105
# [378/595] https://blog.naver.com/sssord12/223998919403
# [379/595] https://blog.naver.com/heevely0522/223902181960
# [380/595] https://blog.naver.com/gonnin
# [381/595] https://blog.naver.com/wotup
# [382/595] https://blog.naver.com/unidus37
# [383/595] https://blog.naver.com/sh-b_7
# [384/595] https://blog.naver.com/creative202566
# [385/595] https://blog.naver.com/kitia5
# [386/595] https://blog.naver.com/thumbnail2021
# [387/595] https://blog.naver.com/nail4season
# [388/595] https://blog.naver.com/organ59564
# [389/595] https://blog.naver.com/jin2_0v0/223900055968
# [390/595] https://blog.naver.com/sm3963
# [391/595] https://blog.naver.com/bbaebbae-
# [392/595] https://blog.naver.com/90x8k3yu
# [393/595] https://blog.naver.com/sosohan_timeslip
# [394/595] https://blog.naver.com/purplencrystal
# [395/595] https://blog.naver.com/yeon21106
# [396/595] https://blog.naver.com/conscious4969
# [397/595] https://blog.naver.com/kyj5141
# [398/595] https://blog.naver.com/sooksong_
# [399/595] https://blog.naver.com/uanalysis
# [400/595] https://blog.naver.com/chitcht88040
# [401/595] https://blog.naver.com/lomi88
# [402/595] https://blog.naver.com/bbobbolee2
# [403/595] https://blog.naver.com/f2mg2
# [404/595] https://blog.naver.com/cafe_wheelie
# [405/595] https://blog.naver.com/seul_gei
# [406/595] https://blog.naver.com/fzs6i9wi
# [407/595] https://blog.naver.com/wonyluv_u
# [408/595] https://blog.naver.com/tnwjd984
# [409/595] https://blog.naver.com/classydressy
# [410/595] https://blog.naver.com/eslightly
# [411/595] https://blog.naver.com/omu_nail
# [412/595] https://blog.naver.com/w14q3nxp
# [413/595] https://blog.naver.com/changwondailynail
# [414/595] https://blog.naver.com/erhill
# [415/595] https://blog.naver.com/reallyna_
# [416/595] https://blog.naver.com/siz_0205
# [417/595] https://blog.naver.com/nailpartykorea
# [418/595] https://blog.naver.com/uandlee_b
# [419/595] https://blog.naver.com/rohhyunji
# [420/595] https://blog.naver.com/nailstroll
# [421/595] https://blog.naver.com/clare8703
# [422/595] https://blog.naver.com/sodam_486
# [423/595] https://blog.naver.com/hjg2828
# [424/595] https://blog.naver.com/sangsang_chowal/224027490180
# [425/595] https://blog.naver.com/jeongadang
# [426/595] https://blog.naver.com/color_uxui
# [427/595] https://blog.naver.com/hseul016
# [428/595] https://blog.naver.com/sjscope
# [429/595] https://blog.naver.com/alsksh234
# [430/595] https://blog.naver.com/theoidjtrio
# [431/595] https://blog.naver.com/whuydgduihe
# [432/595] https://blog.naver.com/dearmisoon
# [433/595] https://blog.naver.com/ua04a85w
# [434/595] https://blog.naver.com/hyseed61981
# [435/595] https://blog.naver.com/euzfynbks
# [436/595] https://blog.naver.com/satisfying202490
# [437/595] https://blog.naver.com/bksgxootk
# [438/595] https://blog.naver.com/lionkang_
# [439/595] https://blog.naver.com/nnskehrhtoji
# [440/595] https://blog.naver.com/gciuhsuiehrjeo
# [441/595] https://blog.naver.com/totalbeauty_bio
# [442/595] https://blog.naver.com/nora200556
# [443/595] https://blog.naver.com/x2qdngv2
# [444/595] https://blog.naver.com/jjyoung9693
# [445/595] https://blog.naver.com/angel9708
# [446/595] https://blog.naver.com/otyge
# [447/595] https://blog.naver.com/nodaysoff
# [448/595] https://blog.naver.com/nnhie
# [449/595] https://blog.naver.com/buildup14204
# [450/595] https://blog.naver.com/gourdhxkimberrxv
# [451/595] https://blog.naver.com/mnym7y1b
# [452/595] https://blog.naver.com/kps4574
# [453/595] https://blog.naver.com/41nzlrqm
# [454/595] https://blog.naver.com/zoey200665
# [455/595] https://blog.naver.com/hjcuxk961
# [456/595] https://blog.naver.com/jashstory
# [457/595] https://blog.naver.com/zo0uzr3h
# [458/595] https://blog.naver.com/rkdtjd93
# [459/595] https://blog.naver.com/ythong88
# [460/595] https://blog.naver.com/10_e_dd
# [461/595] https://blog.naver.com/sbsbeauty_bp
# [462/595] https://blog.naver.com/somzzang__
# [463/595] https://blog.naver.com/twinklebunny/223830720066
# [464/595] https://blog.naver.com/yewon920
# [465/595] https://blog.naver.com/thstjdus0629
# [466/595] https://blog.naver.com/hani0_
# [467/595] https://blog.naver.com/tmprime
# [468/595] https://blog.naver.com/bcd314
# [469/595] https://blog.naver.com/iclick62
# [470/595] https://blog.naver.com/4728282
# [471/595] https://blog.naver.com/sehyangg
# [472/595] https://blog.naver.com/kmyyyy1225
# [473/595] https://blog.naver.com/vanillary88
# [474/595] https://blog.naver.com/yuri_ring-
# [475/595] https://blog.naver.com/wou1103/223889170959
# [476/595] https://blog.naver.com/2honhaza
# [477/595] https://blog.naver.com/glacksclsrn2
# [478/595] https://blog.naver.com/seung2435
# [479/595] https://blog.naver.com/designed_by_ahs
# [480/595] https://blog.naver.com/jung8452
# [481/595] https://blog.naver.com/yuri831211/223880430889
# [482/595] https://blog.naver.com/sera931122
# [483/595] https://blog.naver.com/dmdk42
# [484/595] https://blog.naver.com/mel_holic/223784770278
# [485/595] https://blog.naver.com/mbcbeaut
# [486/595] https://blog.naver.com/tasha81
# [487/595] https://blog.naver.com/azone_01
# [488/595] https://blog.naver.com/yuaszx94
# [489/595] https://blog.naver.com/f2mg1
# [490/595] https://blog.naver.com/blondetoast
# [491/595] https://blog.naver.com/miss_ula/223124805465
# [492/595] https://blog.naver.com/veni_vidivixi
# [493/595] https://blog.naver.com/sofia_sh
# [494/595] https://blog.naver.com/yuna_118
# [495/595] https://blog.naver.com/a_day_of_asso
# [496/595] https://blog.naver.com/zeloeshide
# [497/595] https://blog.naver.com/sine9679
# [498/595] https://blog.naver.com/flowerforseason
# [499/595] https://blog.naver.com/edukini
# [500/595] https://blog.naver.com/haeuni9196
# [501/595] https://blog.naver.com/jsh9353
# [502/595] https://blog.naver.com/dltyd97
# [503/595] https://blog.naver.com/daelhaelmom
# [504/595] https://blog.naver.com/johappy1128
# [505/595] https://blog.naver.com/heechuuu_
# [506/595] https://blog.naver.com/lightempire
# [507/595] https://blog.naver.com/dkfzhdekfzhd002
# [508/595] https://blog.naver.com/arnion12
# [509/595] https://blog.naver.com/skystar0603
# [510/595] https://blog.naver.com/bandinhouse_munjeong
# [511/595] https://blog.naver.com/nobleliz_
# [512/595] https://blog.naver.com/nail4season
# [513/595] https://blog.naver.com/han_8152
# [514/595] https://blog.naver.com/sbsbeautybusan
# [515/595] https://blog.naver.com/jt626
# [516/595] https://blog.naver.com/didrh31
# [517/595] https://blog.naver.com/koe118
# [518/595] https://blog.naver.com/referbqk
# [519/595] https://blog.naver.com/remember5230
# [520/595] https://blog.naver.com/youwant_main
# [521/595] https://blog.naver.com/mingg__d
# [522/595] https://blog.naver.com/jimmini_
# [523/595] https://blog.naver.com/thumbnail2021
# [524/595] https://blog.naver.com/cag8701
# [525/595] https://blog.naver.com/naildistrict
# [526/595] https://blog.naver.com/oouyeon/224061182056
# [527/595] https://blog.naver.com/tkdzma0227
# [528/595] https://blog.naver.com/focl/223825391602
# [529/595] https://blog.naver.com/zathhvrwokt
# [530/595] https://blog.naver.com/isfju
# [531/595] https://blog.naver.com/anna_dhs
# [532/595] https://blog.naver.com/pause10785
# [533/595] https://blog.naver.com/mookdong20
# [534/595] https://blog.naver.com/yesuri_ashley
# [535/595] https://blog.naver.com/heojung89
# [536/595] https://blog.naver.com/yuaszx1217
# [537/595] https://blog.naver.com/sososora_
# [538/595] https://blog.naver.com/asometapk
# [539/595] https://blog.naver.com/charity0650
# [540/595] https://blog.naver.com/wlsruddl998
# [541/595] https://blog.naver.com/iamsohungryyy
# [542/595] https://blog.naver.com/eun_bib
# [543/595] https://blog.naver.com/1-986
# [544/595] https://blog.naver.com/dlwltnr498
# [545/595] https://blog.naver.com/oiunaqettor23536
# [546/595] https://blog.naver.com/l8ptf9c32g
# [547/595] https://blog.naver.com/allthatmakes
# [548/595] https://blog.naver.com/ikaenynisil
# [549/595] https://blog.naver.com/5honghong
# [550/595] https://blog.naver.com/dabbong0812
# [551/595] https://blog.naver.com/sanhonail
# [552/595] https://blog.naver.com/viviana100
# [553/595] https://blog.naver.com/fom05
# [554/595] https://blog.naver.com/lch-98760
# [555/595] https://blog.naver.com/tenadabeauty
# [556/595] https://blog.naver.com/pqunuoi185
# [557/595] https://blog.naver.com/2yoonsun
# [558/595] https://blog.naver.com/miji4080
# [559/595] https://blog.naver.com/cjstkalghk1
# [560/595] https://blog.naver.com/hye_minyyy
# [561/595] https://blog.naver.com/locatefou
# [562/595] https://blog.naver.com/sysysysysy811
# [563/595] https://blog.naver.com/yejinaessi
# [564/595] https://blog.naver.com/zdcoast
# [565/595] https://blog.naver.com/cc202412
# [566/595] https://blog.naver.com/top3753
# [567/595] https://blog.naver.com/starrystarrynight1
# [568/595] https://blog.naver.com/yjk2650
# [569/595] https://blog.naver.com/mszexapfh
# [570/595] https://blog.naver.com/edukin_beauty
# [571/595] https://blog.naver.com/bnmkliop
# [572/595] https://blog.naver.com/freeadcc
# [573/595] https://blog.naver.com/0078556
# [574/595] https://blog.naver.com/92_10_13
# [575/595] https://blog.naver.com/n-finance
# [576/595] https://blog.naver.com/jyrn0514
# [577/595] https://blog.naver.com/seseomdtae
# [578/595] https://blog.naver.com/tjdwkrj
# [579/595] https://blog.naver.com/saranghae7942
# [580/595] https://blog.naver.com/blue27j
# [581/595] https://blog.naver.com/dahae3002
# [582/595] https://blog.naver.com/carriebernard
# [583/595] https://blog.naver.com/fun233
# [584/595] https://blog.naver.com/loverly_art
# [585/595] https://blog.naver.com/732692
# [586/595] https://blog.naver.com/vivi_adventure
# [587/595] https://blog.naver.com/nara2149
# [588/595] https://blog.naver.com/fvrybyc2
# [589/595] https://blog.naver.com/gusgml001216
# [590/595] https://blog.naver.com/tevjcfihr
# [591/595] https://blog.naver.com/dhsmfgkfngodqhr
# [592/595] https://blog.naver.com/totosieun
# [593/595] https://blog.naver.com/onyou9675
# [594/595] https://blog.naver.com/beautydream_
# [595/595] https://blog.naver.com/wldnjsdl9264

# %% [markdown]
# ### CSV 저장

# %%
### CSV 저장
if IS_SAVE_CSV:
    os.makedirs(ROOT_DOWNLOAD_DIR, exist_ok=True)
    df_enriched.to_csv(CSV_PATH, index=False, encoding="utf-8-sig")
    print("CSV 저장 완료:", CSV_PATH)
# Out:
# CSV 저장 완료: craw-download-file\20251120_03_multi.csv

# %%
df_enriched
