# %% [markdown]
# # 네이버 검색 + 블로그 본문 스크랩

# %% [markdown]
# ## 정보 입력 / 전역 설정

# %% [markdown]
# ### 환경 변수

# %%
# 실행 순번 - 경로에 사용
RUN_INDEX = 3                 # !!중요!! - 실행=파일명 순번 => 수동 업데이트

# --- 검색 일자 ---
start_date = '20250101'
end_date = ''                 # 입력 안 하면 오늘 날짜로 세팅

# --- 스크롤 횟수 ---
scroll_times = 10              # 스크롤 횟수

# --- 다운로드 옵션 ---
IS_SAVE_CSV = True            # CSV(엑셀용) 저장 여부
IS_SAVE_IMAGES = False         # 이미지 저장 여부

# --- 파일 다운로드 경로 (ROOT) --
ROOT_DOWNLOAD_DIR = 'craw-download-file'

# %% [markdown]
# ### 검색 키워드 입력

# %%
# 단일 키워드
keyword = '네일추천'            # 검색 키워드
search_keyword = keyword      # 검색창에 넣을 실제 값

# 다중 키워드 (여러번 검색 수행) - 비어 있다면, 단일 키워드로 수행
search_keywords = [
    # # 1) 기본/일반 네일 (베이스 분포용)
    # "네일 추천",
    # "네일 디자인",
    # "셀프네일 디자인",
    # "데일리 네일",
    # "직장인 네일",

    # # 2) 쉐입 중심
    # "라운드 네일 디자인",
    # "오벌 네일 디자인",
    # "스퀘어 네일 디자인",
    # "스퀘어오벌 네일",
    # "아몬드 네일 디자인",

    # 3) 길이·손 특징 중심
    "짧은 손톱 네일",
    "짧은손톱 셀프네일",
    "긴 손톱 네일",
    "손가락 길어보이는 네일",
    "손이 예뻐보이는 네일",
]

# %% [markdown]
# ## 함수 정의

# %% [markdown]
# ### 모듈 import

# %%
import os
import re
import requests
from datetime import datetime
from urllib.parse import urljoin

import pandas as pd
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
import mimetypes

# %% [markdown]
# ### 파일 경로

# %%
## 파일 경로 : 일자 + 실행 순번 + 검색어 or multi

today_date = datetime.now().strftime("%Y%m%d")

def sanitize_keyword(kw: str) -> str:
    """파일/폴더명으로 쓸 수 있게 키워드 정제 """
    if not isinstance(kw, str):
        kw = str(kw)
    kw = kw.strip().strip('"').strip("'")
    # 파일명에 쓸 수 없는 문자 제거
    kw = re.sub(r'[\\/:*?"<>|]', '_', kw)
    # 너무 길면 잘라내기
    if len(kw) == 0:
        kw = "keyword"
    return kw

### 단일/다중에 따라 파일명 기준 키워드 결정
if search_keywords:          # 다중 키워드 리스트가 비어있지 않다면
    base_keyword_for_path = "multi"
else:
    base_keyword_for_path = search_keyword

SAFE_KEYWORD = sanitize_keyword(base_keyword_for_path)

SUB_NAME = f"{today_date}_{RUN_INDEX:02d}_{SAFE_KEYWORD}"

CSV_PATH = os.path.join(ROOT_DOWNLOAD_DIR, f"{SUB_NAME}.csv")
IMAGE_DIR = os.path.join(ROOT_DOWNLOAD_DIR, SUB_NAME)

# %% [markdown]
# ### 날짜 정규화

# %%
import re
from datetime import datetime, timedelta, timezone

KST = timezone(timedelta(hours=9))

_abs = re.compile(r"^\s*(\d{4})\.(\d{1,2})\.(\d{1,2})\.?\s*$")
_m  = re.compile(r"(\d+)\s*분\s*전")
_h  = re.compile(r"(\d+)\s*시간\s*전")
_d  = re.compile(r"(\d+)\s*일\s*전")
_w  = re.compile(r"(\d+)\s*주\s*전")
_not_date_tail = re.compile(r"(?:단|TOP),\s*$")        # 예: "A34면 1단," , "A30면 TOP,"

def _ymd(dt: datetime) -> str:
    # Python/Excel 공통 인식 포맷: YYYY-MM-DD
    return f"{dt.year:04d}-{dt.month:02d}-{dt.day:02d}"

def normalize_news_date(texts, now: datetime | None = None) -> str | None:
    # 변환 실패 대비: 원본 첫 값 보관
    original_first = texts if isinstance(texts, str) else (texts[0] if texts else None)

    if isinstance(texts, str):
        texts = [texts]
    now = now or datetime.now(KST)

    for t in texts:
        if not t:
            continue
        s = t.strip()

        # 지면/면·단, TOP 꼬리면 스킵
        if _not_date_tail.search(s):
            continue

        # 절대형
        m = _abs.match(s)
        if m:
            y, mo, d = map(int, m.groups())
            return f"{y:04d}-{mo:02d}-{d:02d}"

        # 상대형
        if (mm := _h.search(s)): # 분
            return _ymd(now - timedelta(minutes=int(mm.group(1))))
        if (mh := _h.search(s)): # 시간
            return _ymd(now - timedelta(hours=int(mh.group(1))))
        if (md := _d.search(s)): # 일
            return _ymd(now - timedelta(days=int(md.group(1))))
        if (mw := _w.search(s)): # 주
            return _ymd(now - timedelta(weeks=int(mw.group(1))))

    # 날짜형 변환이 안되면 첫 번째 값 반환
    return original_first

# %% [markdown]
# ### 검색 결과 카드 한 개에서 정보 추출

# %%
def get_content(review):
    condic = {}

    title_css  = (
        "span.sds-comps-text.sds-comps-text-ellipsis.sds-comps-text-ellipsis-1"
        ".sds-comps-text-type-headline1.sds-comps-text-weight-sm"
    )
    text_css   = (
        "span.sds-comps-text-type-body1"
    )
    viewer_css = (
        "div.sds-comps-horizontal-layout.sds-comps-inline-layout"
        ".sds-comps-profile-info-title"
    )
    date_css   = (
        "span.sds-comps-text.sds-comps-text-type-body2"
        ".sds-comps-text-weight-sm.sds-comps-profile-info-subtext"
    )
    link_css   = 'a[href*="blog.naver.com"]'

    condic['writer'] = review.find_element(By.CSS_SELECTOR, viewer_css) \
                             .get_attribute('innerText').strip()
    condic['title'] = review.find_element(By.CSS_SELECTOR, title_css) \
                             .get_attribute('innerText').strip()
    condic['text'] = review.find_element(By.CSS_SELECTOR, text_css) \
                            .get_attribute('innerText').strip()
    condic['date'] = normalize_news_date(
        review.find_element(By.CSS_SELECTOR, date_css)
              .get_attribute('innerText').strip()
    )
    try:
        condic['link'] = review.find_element(By.CSS_SELECTOR, link_css) \
                                .get_attribute('href')
    except Exception:
        condic['link'] = ''
        print(f"condic['link'] -> 추출오류 : {condic['title']}")

    return condic

# %% [markdown]
# ### 블로그 본문 크롤링 + 이미지 저장

# %%
def crawl_blog_content(url: str, search_idx: int,
                       image_dir: str,
                       is_download_images: bool = True):

    COMMON_HEADERS = {"User-Agent": "Mozilla/5.0"}

    resp = requests.get(url, headers=COMMON_HEADERS)
    resp.raise_for_status()
    soup = BeautifulSoup(resp.text, "html.parser")

    # iframe 찾기
    iframe = soup.select_one("iframe#mainFrame")
    if iframe is None:
        for f in soup.find_all("iframe"):
            src = f.get("src") or ""
            if "PostView" in src:
                iframe = f
                break

    if iframe is None:
        print(f"[WARN] iframe 없음 → {url}")
        return {"title": "", "full_text": "", "image_count": 0}

    inner_src = iframe.get("src")
    inner_url = urljoin(resp.url, inner_src)

    # iframe 안쪽 요청
    resp2 = requests.get(inner_url, headers=COMMON_HEADERS)
    resp2.raise_for_status()
    soup2 = BeautifulSoup(resp2.text, "html.parser")

    # 제목
    title_tag = soup2.find("title")
    title = title_tag.get_text(strip=True) if title_tag else ""

    # 본문 텍스트
    paragraphs = [p.get_text(" ", strip=True) for p in soup2.find_all("p")]
    full_text = "\n".join(paragraphs)

    if not full_text.strip():
        main_div = soup2.select_one("div.se-main-container")
        if main_div:
            paragraphs = [
                p.get_text(" ", strip=True)
                for p in main_div.find_all(["p", "span"])
            ]
            full_text = "\n".join(paragraphs)

    # 이미지 다운로드
    image_count = 0
    if is_download_images:
        content = (
            soup2.select_one("div.se-main-container")
            or soup2.select_one("#postViewArea")
            or soup2
        )
        img_tags = content.find_all("img")

        os.makedirs(image_dir, exist_ok=True)

        allowed_hosts = ("postfiles.pstatic.net", "blogfiles.pstatic.net")

        for img_idx, img in enumerate(img_tags, start=1):
            src = img.get("data-origin") or img.get("data-src") or img.get("src")
            if not src:
                continue

            if not any(h in src for h in allowed_hosts):
                continue

            if src.startswith("//"):
                src = "https:" + src
            elif src.startswith("/"):
                src = urljoin(inner_url, src)
            if src.startswith("data:"):
                continue

            hi_src = src
            if "type=w80_blur" in src:
                hi_src = src.replace("type=w80_blur", "type=w966")

            img_headers = {
                "User-Agent": "Mozilla/5.0",
                "Referer": inner_url,
            }

            img_resp = None
            for candidate in [hi_src, src]:
                try:
                    r = requests.get(candidate, headers=img_headers, timeout=10)
                    r.raise_for_status()
                    img_resp = r
                    break
                except Exception:
                    img_resp = None

            if img_resp is None:
                continue

            content_type = img_resp.headers.get("Content-Type", "")
            if "image" not in content_type:
                continue

            if not is_download_images:
                image_count += 1
                continue

            ext = mimetypes.guess_extension(content_type.split(";")[0]) or ".jpg"

            # IMG_{검색결과순번 4자리}_{본문내 이미지순번 4자리}
            filename = os.path.join(
                image_dir,
                f"IMG_{search_idx:04d}_{img_idx:04d}{ext}"
            )

            with open(filename, "wb") as f:
                f.write(img_resp.content)

            image_count += 1

    return {
        "title": title,
        "full_text": full_text,
        "image_count": image_count,
    }


def enrich_with_blog_contents(df_search: pd.DataFrame) -> pd.DataFrame:
    """
    1번 검색 df 기준:
    - title 덮어쓰기 (블로그 실제 제목)
    - full_text 열 추가
    - image_count 열 추가
    """

    df = df_search.copy()
    df["full_text"] = ""
    df["image_count"] = 0

    for idx, row in df.iterrows():
        url = row.get("link", "")
        if not isinstance(url, str) or not url.strip():
            continue

        search_idx = idx + 1
        print(f"[{search_idx}/{len(df)}] {url}")

        info = crawl_blog_content(
            url=url,
            search_idx=search_idx,
            image_dir=IMAGE_DIR,
            is_download_images=IS_SAVE_IMAGES
        )

        df.at[idx, "title"] = info["title"]
        df.at[idx, "full_text"] = info["full_text"]
        df.at[idx, "image_count"] = info["image_count"]

    return df

# %% [markdown]
# ## 실행부

# %% [markdown]
# ### 검색 페이지 로드 / 스크롤 / 본문 스크랩

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from urllib.parse import quote_plus

from time import sleep
import random

def encode_keyword(search_keyword: str) -> str:
    return quote_plus(search_keyword)

driver = webdriver.Chrome()

# 다중 키워드가 있으면 그걸 사용, 없으면 단일 search_keyword 사용
if search_keywords:
    keywords_to_run = search_keywords
else:
    keywords_to_run = [search_keyword]

all_results = []

for q in keywords_to_run:
    print(f"\n=== 검색 시작: {q} ===")
    enc_q = encode_keyword(q)

    url = (
        "https://search.naver.com/search.naver"
        "?ssc=tab.blog.all"
        "&sm=tab_opt"
        "&where=blog"
        f"&query={enc_q}"
        f"&nso=so%3Ar%2Cp%3Afrom{start_date}to{end_date}"
    )

    driver.get(url)

    # 스크롤
    xp = '/html'
    review_box = driver.find_element(By.XPATH, xp)

    for _ in range(scroll_times):
        driver.execute_script('arguments[0].scrollTop = arguments[0].scrollHeight', review_box)
        sleep(random.randint(2, 3))

    # 박스 선택
    forms = driver.find_elements(
        By.CSS_SELECTOR,
        'div.sds-comps-vertical-layout.sds-comps-full-layout.YNThgbNOBFUb3Wc2Cq47'
    )
    print('박스 수 :', len(forms))

    # 카드별 정보 수집
    success = 0
    # fail_stats = {}
    for i, form in enumerate(forms, start=1):
        try:
            dic = get_content(form)
            dic["search_keyword"] = q   # 어떤 검색어에서 나온 결과인지 기록
            all_results.append(dic)
            success += 1
        except Exception as e:
            name = type(e).__name__
            # fail_stats[name] = fail_stats.get(name, 0) + 1
            # print(f"[{q}] 카드 {i}/{len(forms)} skip → {name}: {e}")

    # print(f"[{q}] 성공: {success} / {len(forms)}")
    # print(f"[{q}] 실패 통계: {fail_stats}")

# 모든 결과를 하나의 DataFrame으로
df_search = pd.DataFrame(all_results)
print("총 수집 건수:", len(df_search))


df_search['idx'] = range(len(df_search))

cols = (['idx', 'search_keyword']
        + [c for c in df_search.columns if c not in ['idx', 'search_keyword']])
df_search = df_search[cols]

df_search.head()
# Out:
# === 검색 시작: 짧은 손톱 네일 ===
# 박스 수 : 122
#
# === 검색 시작: 짧은손톱 셀프네일 ===
# 박스 수 : 135
#
# === 검색 시작: 긴 손톱 네일 ===
# 박스 수 : 113
#
# === 검색 시작: 손가락 길어보이는 네일 ===
# 박스 수 : 138
#
# === 검색 시작: 손이 예뻐보이는 네일 ===
# 박스 수 : 145
# 총 수집 건수: 653
#    idx search_keyword       writer  \
# 0    0       짧은 손톱 네일  해오름달 하루, 수진
# 1    1       짧은 손톱 네일    개복치의 일상생활
# 2    2       짧은 손톱 네일     나는 부엉이✨️
# 3    3       짧은 손톱 네일         제이와이
# 4    4       짧은 손톱 네일   @hyo_kkang
#
#                                                title  \
# 0                  잠실역네일아트 잘하는곳 벨라네일 짧은손톱네일아트 디자인 추천
# 1                        가로수길네일 오운스네일샵, 유니크한 짧은손톱 네일
# 2            망원역 네일샵 추천 조이네일랜드 문제성 손톱 관리 짧은손톱네일 잘하는곳
# 3                           검단 늘뷰티스튜디오 귀여운 짧은손톱 네일아트
# 4  논현역 짧은손톱 네일 구원! '원스뷰티룸 논현본점'에서 인생 네일 받고 센스 넘치는...
#
#                                                 text        date  \
# 0  한 달에 한 번 네일 바꾸고 싶을 때마다 생각나는 잠실역 네일아트 잘하는 곳 벨라네...  2025-11-06
# 1  연예인들은 짧은손톱도 넘 귀엽던데 내가하면 왠지 좀 뭉툭해보여...하는분들 짧은손톱...  2025-08-25
# 2  받을 수 있는 망원역 네일샵 <조이네일랜드> 꼬옥 방문해보세용 #마포네일샵 #홍대네...  2025-10-23
# 3  안녕하세요 제이와이예요 :-) 저번에 길었던 손톱을 싹 다듬고 이번에 짧은손톱 네일...  2025-07-23
# 4  논현역 짧은손톱 네일도 예쁘게 받을 수 있다는 소문에 완전 기대했어요 짧은 손톱도 ...  2025-09-20
#
#                                              link
# 0                 https://blog.naver.com/suzin___
# 1               https://blog.naver.com/realblue88
# 2               https://blog.naver.com/boo______1
# 3  https://blog.naver.com/sunkjydbgn/223944212796
# 4            https://blog.naver.com/remember_0629

# %% [markdown]
# ### 블로그 본문 + 이미지 수집

# %%
### 블로그 본문 + 이미지 수집
if IS_SAVE_IMAGES or True :   # 이미지 저장 안하더라도 본문 수집은 수행
    df_enriched = enrich_with_blog_contents(df_search)
else:
    df_enriched = df_search.copy()
# Out:
# [1/653] https://blog.naver.com/suzin___
# [2/653] https://blog.naver.com/realblue88
# [3/653] https://blog.naver.com/boo______1
# [4/653] https://blog.naver.com/sunkjydbgn/223944212796
# [5/653] https://blog.naver.com/remember_0629
# [6/653] https://blog.naver.com/beautyforfuture
# [7/653] https://blog.naver.com/sweetjo/224009380457
# [8/653] https://blog.naver.com/eunhye2727
# [9/653] https://blog.naver.com/tbzm32
# [10/653] https://blog.naver.com/beautiqueleelune/223899979905
# [11/653] https://blog.naver.com/as06123
# [12/653] https://blog.naver.com/smjd22
# [13/653] https://blog.naver.com/kenshin1477
# [14/653] https://blog.naver.com/bongbong323
# [15/653] https://blog.naver.com/zixnee
# [16/653] https://blog.naver.com/tory0413
# [17/653] https://blog.naver.com/dyoing-
# [18/653] https://blog.naver.com/doosonnail
# [19/653] https://blog.naver.com/hnoni863
# [20/653] https://blog.naver.com/sonji76/223435819366
# [21/653] https://blog.naver.com/zzinwave
# [22/653] https://blog.naver.com/melonheads/223598608732
# [23/653] https://blog.naver.com/mink616
# [24/653] https://blog.naver.com/shyivy7
# [25/653] https://blog.naver.com/lovely_227/224000855386
# [26/653] https://blog.naver.com/limychacha_
# [27/653] https://blog.naver.com/pjj3462
# [28/653] https://blog.naver.com/arsoap
# [29/653] https://blog.naver.com/purinaru
# [30/653] https://blog.naver.com/levely3294/223962843553
# [31/653] https://blog.naver.com/babo2511
# [32/653] https://blog.naver.com/addagirl2
# [33/653] https://blog.naver.com/sjynobby
# [34/653] https://blog.naver.com/toaaud
# [35/653] https://blog.naver.com/fiat710/223906257299
# [36/653] https://blog.naver.com/miranmiran01
# [37/653] https://blog.naver.com/pump0082
# [38/653] https://blog.naver.com/yoonhye_1004
# [39/653] https://blog.naver.com/kassiakim/222679275917
# [40/653] https://blog.naver.com/hello_1525
# [41/653] https://blog.naver.com/chyu067
# [42/653] https://blog.naver.com/tls5175/224045235821
# [43/653] https://blog.naver.com/e55gp0x0vbe
# [44/653] https://blog.naver.com/vinmongz
# [45/653] https://blog.naver.com/chopa07_
# [46/653] https://blog.naver.com/25artist/223915768311
# [47/653] https://blog.naver.com/layeonparkgogo/224010711354
# [48/653] https://blog.naver.com/j90101
# [49/653] https://blog.naver.com/doublesholdings/223965582005
# [50/653] https://blog.naver.com/cinnamon0412/223707400572
# [51/653] https://blog.naver.com/lry123
# [52/653] https://blog.naver.com/9x3tc4m9
# [53/653] https://blog.naver.com/jungeun9019/223988259355
# [54/653] https://blog.naver.com/dal_damda_
# [55/653] https://blog.naver.com/hey_pepper
# [56/653] https://blog.naver.com/r3bpqrid
# [57/653] https://blog.naver.com/uxxdenim
# [58/653] https://blog.naver.com/incident6225
# [59/653] https://blog.naver.com/banggeul07/223727105476
# [60/653] https://blog.naver.com/bomby_
# [61/653] https://blog.naver.com/difma2616
# [62/653] https://blog.naver.com/guswjd4236
# [63/653] https://blog.naver.com/leeke1214
# [64/653] https://blog.naver.com/1oo4zz/223973517838
# [65/653] https://blog.naver.com/j-sun
# [66/653] https://blog.naver.com/gbwl0l00
# [67/653] https://blog.naver.com/clsrn9606
# [68/653] https://blog.naver.com/liebe7173
# [69/653] https://blog.naver.com/052young
# [70/653] https://blog.naver.com/cwdyusbe
# [71/653] https://blog.naver.com/2r0baalm
# [72/653] https://blog.naver.com/2_sini
# [73/653] https://blog.naver.com/efflorescence22706
# [74/653] https://blog.naver.com/eungyeong_5
# [75/653] https://blog.naver.com/i4l44ywk
# [76/653] https://blog.naver.com/bettermom_hani
# [77/653] https://blog.naver.com/fvrybyc2
# [78/653] https://blog.naver.com/dlj2zq4n
# [79/653] https://blog.naver.com/if4j8s29
# [80/653] https://blog.naver.com/nail_chowon
# [81/653] https://blog.naver.com/mpilapole
# [82/653] https://blog.naver.com/happymin_life
# [83/653] https://blog.naver.com/rara_juju
# [84/653] https://blog.naver.com/huchu_1028
# [85/653] https://blog.naver.com/dong2_94
# [86/653] https://blog.naver.com/jsh1190301
# [87/653] https://blog.naver.com/cnodtilew
# [88/653] https://blog.naver.com/mini_bella_520
# [89/653] https://blog.naver.com/hee7945
# [90/653] https://blog.naver.com/pieceofjourney
# [91/653] https://blog.naver.com/addfk81
# [92/653] https://blog.naver.com/s016653
# [93/653] https://blog.naver.com/wlsdudwhdals
# [94/653] https://blog.naver.com/fprbfn2182
# [95/653] https://blog.naver.com/madeindohyun
# [96/653] https://blog.naver.com/e8wkl8l3
# [97/653] https://blog.naver.com/euntill
# [98/653] https://blog.naver.com/brighten1018
# [99/653] https://blog.naver.com/8810020
# [100/653] https://blog.naver.com/8y8d4xsv
# [101/653] https://blog.naver.com/lobs_inside
# [102/653] https://blog.naver.com/d36qxw3g9lc
# [103/653] https://blog.naver.com/alohanail
# [104/653] https://blog.naver.com/ua8ly08y
# [105/653] https://blog.naver.com/hxx2knqbuga
# [106/653] https://blog.naver.com/ghujn
# [107/653] https://blog.naver.com/ria_world
# [108/653] https://blog.naver.com/nyampopo
# [109/653] https://blog.naver.com/dduction96684
# [110/653] https://blog.naver.com/nailj-j
# [111/653] https://blog.naver.com/hf2b1o2l
# [112/653] https://blog.naver.com/skadpddms
# [113/653] https://blog.naver.com/snour
# [114/653] https://blog.naver.com/rx37iv60
# [115/653] https://blog.naver.com/lo6jy5qcyd
# [116/653] https://blog.naver.com/e54xrdt1
# [117/653] https://blog.naver.com/mlvqb5jt
# [118/653] https://blog.naver.com/tlce8rli
# [119/653] https://blog.naver.com/bonnebong
# [120/653] https://blog.naver.com/hj10061
# [121/653] https://blog.naver.com/seowongang3
# [122/653] https://blog.naver.com/ynh3377/223970951374
# [123/653] https://blog.naver.com/qmfosej/223373544765
# [124/653] https://blog.naver.com/g19950
# [125/653] https://blog.naver.com/lucidsme/223904812710
# [126/653] https://blog.naver.com/tjdbs0323/223867380025
# [127/653] https://blog.naver.com/kyj5141
# [128/653] https://blog.naver.com/2090063
# [129/653] https://blog.naver.com/naileun_shop
# [130/653] https://blog.naver.com/heighten99126
# [131/653] https://blog.naver.com/sheep1191
# [132/653] https://blog.naver.com/nagi_729/224041254251
# [133/653] https://blog.naver.com/suyako/223415592283
# [134/653] https://blog.naver.com/abirdcage/224044950588
# [135/653] https://blog.naver.com/janiary
# [136/653] https://blog.naver.com/zygcvltbq
# [137/653] https://blog.naver.com/abc_77777
# [138/653] https://blog.naver.com/2un4wrgr
# [139/653] https://blog.naver.com/rjs930
# [140/653] https://blog.naver.com/t1tew02v
# [141/653] https://blog.naver.com/farbemaria/224074455772
# [142/653] https://blog.naver.com/marryplus77
# [143/653] https://blog.naver.com/aboutcheny
# [144/653] https://blog.naver.com/minuit_j/222622502583
# [145/653] https://blog.naver.com/dlgpwls9459/223043080517
# [146/653] https://blog.naver.com/abalico
# [147/653] https://blog.naver.com/mrschihuahua
# [148/653] https://blog.naver.com/kimchanel1
# [149/653] https://blog.naver.com/backsu_nail
# [150/653] https://blog.naver.com/0226orange/223722489420
# [151/653] https://blog.naver.com/bijoubitna/223446138938
# [152/653] https://blog.naver.com/lalad
# [153/653] https://blog.naver.com/jossa0428
# [154/653] https://blog.naver.com/welove284/223602016235
# [155/653] https://blog.naver.com/misavely/223683688860
# [156/653] https://blog.naver.com/fairyviolet/224059008486
# [157/653] https://blog.naver.com/minimouse24/224015499241
# [158/653] https://blog.naver.com/m_a_u_
# [159/653] https://blog.naver.com/0shjw1p5
# [160/653] https://blog.naver.com/ksy170618
# [161/653] https://blog.naver.com/nail_chowon
# [162/653] https://blog.naver.com/gaglardi
# [163/653] https://blog.naver.com/ssong_0918/223444100922
# [164/653] https://blog.naver.com/yxz2fjhq
# [165/653] https://blog.naver.com/cinnamon0412/223707400572
# [166/653] https://blog.naver.com/wjihdygfug
# [167/653] https://blog.naver.com/iuf9v0l3
# [168/653] https://blog.naver.com/banggeul07/223598230343
# [169/653] https://blog.naver.com/fq93nx27
# [170/653] https://blog.naver.com/o7bubi4m
# [171/653] https://blog.naver.com/sedongne_
# [172/653] https://blog.naver.com/unique202565
# [173/653] https://blog.naver.com/cnnul71386
# [174/653] https://blog.naver.com/pojdwe3957
# [175/653] https://blog.naver.com/86ooqqg3
# [176/653] https://blog.naver.com/aegoya
# [177/653] https://blog.naver.com/35jlyi8f
# [178/653] https://blog.naver.com/170695
# [179/653] https://blog.naver.com/ddidudidu
# [180/653] https://blog.naver.com/vmuatge4
# [181/653] https://blog.naver.com/mrw74917
# [182/653] https://blog.naver.com/wldms021
# [183/653] https://blog.naver.com/rx37iv60
# [184/653] https://blog.naver.com/wononce_
# [185/653] https://blog.naver.com/60otd6xm
# [186/653] https://blog.naver.com/lovedme1346
# [187/653] https://blog.naver.com/layeonparkgogo/224034838468
# [188/653] https://blog.naver.com/siy879
# [189/653] https://blog.naver.com/u8vfqgmj
# [190/653] https://blog.naver.com/x1prejvf
# [191/653] https://blog.naver.com/36yx6uzp
# [192/653] https://blog.naver.com/kdy2638
# [193/653] https://blog.naver.com/fjmskeit
# [194/653] https://blog.naver.com/wkfka88/224033333216
# [195/653] https://blog.naver.com/1fq3rfwp5h
# [196/653] https://blog.naver.com/minji7907
# [197/653] https://blog.naver.com/bori_ggori
# [198/653] https://blog.naver.com/xti4selh
# [199/653] https://blog.naver.com/seulvely_life
# [200/653] https://blog.naver.com/dd030_
# [201/653] https://blog.naver.com/elizabeth200650
# [202/653] https://blog.naver.com/oooo_yes
# [203/653] https://blog.naver.com/kiv87809
# [204/653] https://blog.naver.com/soulmate504
# [205/653] https://blog.naver.com/byhamzu
# [206/653] https://blog.naver.com/q1bwjb7j
# [207/653] https://blog.naver.com/determined202637_
# [208/653] https://blog.naver.com/hensister09
# [209/653] https://blog.naver.com/nail_zzang
# [210/653] https://blog.naver.com/hyeona4585
# [211/653] https://blog.naver.com/ppo0o0ori
# [212/653] https://blog.naver.com/billionaire77777
# [213/653] https://blog.naver.com/cutefoodie
# [214/653] https://blog.naver.com/kimch913
# [215/653] https://blog.naver.com/seheesay_
# [216/653] https://blog.naver.com/yoongu0
# [217/653] https://blog.naver.com/kdseul33
# [218/653] https://blog.naver.com/fly_jian/224007429242
# [219/653] https://blog.naver.com/imurstar66
# [220/653] https://blog.naver.com/hmustkl7765
# [221/653] https://blog.naver.com/lovedarl2/223043515108
# [222/653] https://blog.naver.com/r4th26wo
# [223/653] https://blog.naver.com/ggoolblog
# [224/653] https://blog.naver.com/aa9441
# [225/653] https://blog.naver.com/loveandlook7
# [226/653] https://blog.naver.com/miss5d
# [227/653] https://blog.naver.com/helloworld216
# [228/653] https://blog.naver.com/bwteukc
# [229/653] https://blog.naver.com/qhoghfojtk
# [230/653] https://blog.naver.com/madeindohyun
# [231/653] https://blog.naver.com/marigold_04
# [232/653] https://blog.naver.com/pma0012/223066928134
# [233/653] https://blog.naver.com/jinicupid
# [234/653] https://blog.naver.com/handding2
# [235/653] https://blog.naver.com/kgy620
# [236/653] https://blog.naver.com/das06115
# [237/653] https://blog.naver.com/theboung2
# [238/653] https://blog.naver.com/dlqhdms90111
# [239/653] https://blog.naver.com/babybluepink
# [240/653] https://blog.naver.com/kmy000403
# [241/653] https://blog.naver.com/reno01/222778260201
# [242/653] https://blog.naver.com/levely3294/223824181394
# [243/653] https://blog.naver.com/heehee_jae
# [244/653] https://blog.naver.com/wb04dj4b
# [245/653] https://blog.naver.com/xfxaswixp
# [246/653] https://blog.naver.com/u3xxfsqv
# [247/653] https://blog.naver.com/springmincos
# [248/653] https://blog.naver.com/9in4ikpqj
# [249/653] https://blog.naver.com/pologetics92867
# [250/653] https://blog.naver.com/haru_living
# [251/653] https://blog.naver.com/bettersu_today
# [252/653] https://blog.naver.com/87pv6gfx
# [253/653] https://blog.naver.com/wken29160
# [254/653] https://blog.naver.com/kvpx4mp
# [255/653] https://blog.naver.com/fjy31760
# [256/653] https://blog.naver.com/9v11660q
# [257/653] https://blog.naver.com/5jvvimds
# [258/653] https://blog.naver.com/doosonnail
# [259/653] https://blog.naver.com/rho48526
# [260/653] https://blog.naver.com/nanwonee
# [261/653] https://blog.naver.com/gjwlsrud
# [262/653] https://blog.naver.com/sew6588
# [263/653] https://blog.naver.com/yhand1204
# [264/653] https://blog.naver.com/tizhrwa81
# [265/653] https://blog.naver.com/har0913
# [266/653] https://blog.naver.com/eunhye2727
# [267/653] https://blog.naver.com/ghdwjddml37491
# [268/653] https://blog.naver.com/wwsjid5412
# [269/653] https://blog.naver.com/leegun0917
# [270/653] https://blog.naver.com/mink616
# [271/653] https://blog.naver.com/h27cdwd9tjj48
# [272/653] https://blog.naver.com/as06123
# [273/653] https://blog.naver.com/sonji76/223435819366
# [274/653] https://blog.naver.com/alohanail
# [275/653] https://blog.naver.com/shyivy7
# [276/653] https://blog.naver.com/tory0413
# [277/653] https://blog.naver.com/purinaru
# [278/653] https://blog.naver.com/pedibene_wonju
# [279/653] https://blog.naver.com/sjynobby
# [280/653] https://blog.naver.com/ooooo2_2
# [281/653] https://blog.naver.com/addagirl2
# [282/653] https://blog.naver.com/sp6402
# [283/653] https://blog.naver.com/daily_vely
# [284/653] https://blog.naver.com/spr323
# [285/653] https://blog.naver.com/babo2511
# [286/653] https://blog.naver.com/28blue_sky
# [287/653] https://blog.naver.com/nail_lucky_
# [288/653] https://blog.naver.com/arsoap
# [289/653] https://blog.naver.com/hans_way
# [290/653] https://blog.naver.com/ymodee/222606301867
# [291/653] https://blog.naver.com/tjdbs0323/222878492272
# [292/653] https://blog.naver.com/kristina_krasnova_91
# [293/653] https://blog.naver.com/nw9493
# [294/653] https://blog.naver.com/mini_bella_520
# [295/653] https://blog.naver.com/re_playy
# [296/653] https://blog.naver.com/gmldi7515
# [297/653] https://blog.naver.com/remember_0629
# [298/653] https://blog.naver.com/okhana_
# [299/653] https://blog.naver.com/incident6225
# [300/653] https://blog.naver.com/kcg6414
# [301/653] https://blog.naver.com/hyejin_0519
# [302/653] https://blog.naver.com/jeyelash2911
# [303/653] https://blog.naver.com/fiat710/223906257299
# [304/653] https://blog.naver.com/beautiqueleelune/223899979905
# [305/653] https://blog.naver.com/levely3294/223909301320
# [306/653] https://blog.naver.com/hee7945
# [307/653] https://blog.naver.com/fall_in_autumn
# [308/653] https://blog.naver.com/kyj5141
# [309/653] https://blog.naver.com/artdazz
# [310/653] https://blog.naver.com/dal_damda_
# [311/653] https://blog.naver.com/layeonparkgogo/224010711354
# [312/653] https://blog.naver.com/j90101
# [313/653] https://blog.naver.com/snella_nail
# [314/653] https://blog.naver.com/bettermom_hani
# [315/653] https://blog.naver.com/hello_1525
# [316/653] https://blog.naver.com/2_sini
# [317/653] https://blog.naver.com/banggeul07/223727105476
# [318/653] https://blog.naver.com/skadpddms
# [319/653] https://blog.naver.com/99tailfox
# [320/653] https://blog.naver.com/tbzm32
# [321/653] https://blog.naver.com/jsh1190301
# [322/653] https://blog.naver.com/yebbeojineun_
# [323/653] https://blog.naver.com/brighten1018
# [324/653] https://blog.naver.com/00bora00
# [325/653] https://blog.naver.com/dduzikr
# [326/653] https://blog.naver.com/hxkollo
# [327/653] https://blog.naver.com/taeri0901
# [328/653] https://blog.naver.com/soyen5046
# [329/653] https://blog.naver.com/hj10061
# [330/653] https://blog.naver.com/cehysdm1
# [331/653] https://blog.naver.com/nail_diva
# [332/653] https://blog.naver.com/wlduddl0112
# [333/653] https://blog.naver.com/ygyg1256
# [334/653] https://blog.naver.com/thdud9012
# [335/653] https://blog.naver.com/aqoopa
# [336/653] https://blog.naver.com/saebit__nail
# [337/653] https://blog.naver.com/evidentantlion
# [338/653] https://blog.naver.com/hofykk
# [339/653] https://blog.naver.com/blondeblackbird
# [340/653] https://blog.naver.com/hiyoung_nail
# [341/653] https://blog.naver.com/muimui_
# [342/653] https://blog.naver.com/gaheuneom
# [343/653] https://blog.naver.com/exceptionalcobra
# [344/653] https://blog.naver.com/celebrat7316
# [345/653] https://blog.naver.com/drivinggibbon
# [346/653] https://blog.naver.com/levelorca
# [347/653] https://blog.naver.com/janiary
# [348/653] https://blog.naver.com/savetherani
# [349/653] https://blog.naver.com/prospectivegoose
# [350/653] https://blog.naver.com/chixs_nail
# [351/653] https://blog.naver.com/iorctnshi048
# [352/653] https://blog.naver.com/ook2012
# [353/653] https://blog.naver.com/nuclearleech
# [354/653] https://blog.naver.com/honey_pigtori
# [355/653] https://blog.naver.com/udong2025
# [356/653] https://blog.naver.com/iooi032
# [357/653] https://blog.naver.com/fly_nail
# [358/653] https://blog.naver.com/songwow_
# [359/653] https://blog.naver.com/akfn10136
# [360/653] https://blog.naver.com/seymc2
# [361/653] https://blog.naver.com/yosamity1023
# [362/653] https://blog.naver.com/hellodany_/223384090648
# [363/653] https://blog.naver.com/052young
# [364/653] https://blog.naver.com/misskjy1101
# [365/653] https://blog.naver.com/dirty12838
# [366/653] https://blog.naver.com/eyeettry
# [367/653] https://blog.naver.com/uu266
# [368/653] https://blog.naver.com/angelababy88
# [369/653] https://blog.naver.com/hjung9612
# [370/653] https://blog.naver.com/llb911
# [371/653] https://blog.naver.com/dbrud35/223926709172
# [372/653] https://blog.naver.com/o2oo_o/223752048317
# [373/653] https://blog.naver.com/s5o0f7i1a9
# [374/653] https://blog.naver.com/lqud/224033566632
# [375/653] https://blog.naver.com/har0913
# [376/653] https://blog.naver.com/pby0437
# [377/653] https://blog.naver.com/iambeautylove
# [378/653] https://blog.naver.com/rlathdus157
# [379/653] https://blog.naver.com/windywitch
# [380/653] https://blog.naver.com/therealb
# [381/653] https://blog.naver.com/qufqlc08/223925898710
# [382/653] https://blog.naver.com/minji8635
# [383/653] https://blog.naver.com/nterm
# [384/653] https://blog.naver.com/juvide
# [385/653] https://blog.naver.com/glowforyou_
# [386/653] https://blog.naver.com/486xhxh
# [387/653] https://blog.naver.com/jieun0327
# [388/653] https://blog.naver.com/tjdbs0323/224077123725
# [389/653] https://blog.naver.com/happyendingismine0_0
# [390/653] https://blog.naver.com/vd_r1
# [391/653] https://blog.naver.com/yuki0720
# [392/653] https://blog.naver.com/yu-ri
# [393/653] https://blog.naver.com/nailofdemain
# [394/653] https://blog.naver.com/kikiao12
# [395/653] https://blog.naver.com/fallrain94
# [396/653] https://blog.naver.com/hanvit_lol
# [397/653] https://blog.naver.com/chois909/224081066778
# [398/653] https://blog.naver.com/rlawlgo85
# [399/653] https://blog.naver.com/doosonnail
# [400/653] https://blog.naver.com/blackholecd/224054854209
# [401/653] https://blog.naver.com/melrosequeen
# [402/653] https://blog.naver.com/sinjous
# [403/653] https://blog.naver.com/choro_ogi
# [404/653] https://blog.naver.com/mink616
# [405/653] https://blog.naver.com/bintorynim/224070273212
# [406/653] https://blog.naver.com/viviankk
# [407/653] https://blog.naver.com/algus744
# [408/653] https://blog.naver.com/goodse7/224041409015
# [409/653] https://blog.naver.com/mhub2373
# [410/653] https://blog.naver.com/gjfkfk38317
# [411/653] https://blog.naver.com/pretty4415
# [412/653] https://blog.naver.com/ms21775
# [413/653] https://blog.naver.com/memoofme
# [414/653] https://blog.naver.com/yuri_ring-
# [415/653] https://blog.naver.com/ys_yg_/224075338378
# [416/653] https://blog.naver.com/f2mg1
# [417/653] https://blog.naver.com/ejs1941
# [418/653] https://blog.naver.com/phmphm1211
# [419/653] https://blog.naver.com/kjiwon1018
# [420/653] https://blog.naver.com/i_loveny
# [421/653] https://blog.naver.com/mekyo79
# [422/653] https://blog.naver.com/hearteffect/223947260340
# [423/653] https://blog.naver.com/pppmh0827/223967600257
# [424/653] https://blog.naver.com/aboutcheny
# [425/653] https://blog.naver.com/jytgh
# [426/653] https://blog.naver.com/zipurak1
# [427/653] https://blog.naver.com/incompletegirl/223447433160
# [428/653] https://blog.naver.com/eunbyeol11/222713082777
# [429/653] https://blog.naver.com/woailuxu
# [430/653] https://blog.naver.com/miwoomiwoo27
# [431/653] https://blog.naver.com/mini7254
# [432/653] https://blog.naver.com/dpsk950119
# [433/653] https://blog.naver.com/silver1979_
# [434/653] https://blog.naver.com/naomiek
# [435/653] https://blog.naver.com/subeen97
# [436/653] https://blog.naver.com/natahlie
# [437/653] https://blog.naver.com/doun0112
# [438/653] https://blog.naver.com/thdud9012
# [439/653] https://blog.naver.com/ll_ll88
# [440/653] https://blog.naver.com/leesy_8520
# [441/653] https://blog.naver.com/mini_kkobugi
# [442/653] https://blog.naver.com/epro83
# [443/653] https://blog.naver.com/angelasong0814/224037404949
# [444/653] https://blog.naver.com/3meee
# [445/653] https://blog.naver.com/wotup
# [446/653] https://blog.naver.com/ajajdma
# [447/653] https://blog.naver.com/supra3000
# [448/653] https://blog.naver.com/chunwoo00
# [449/653] https://blog.naver.com/extraordinary5873
# [450/653] https://blog.naver.com/jhw10922
# [451/653] https://blog.naver.com/dirty12838
# [452/653] https://blog.naver.com/jsjjsj8
# [453/653] https://blog.naver.com/hikoo_nail
# [454/653] https://blog.naver.com/ttujji_
# [455/653] https://blog.naver.com/romadak
# [456/653] https://blog.naver.com/toongtoong_s2
# [457/653] https://blog.naver.com/ecqcz304
# [458/653] https://blog.naver.com/islgoilzmm
# [459/653] https://blog.naver.com/ruca41
# [460/653] https://blog.naver.com/fruityoun
# [461/653] https://blog.naver.com/ehowlgksk
# [462/653] https://blog.naver.com/loveeg
# [463/653] https://blog.naver.com/junique629
# [464/653] https://blog.naver.com/2030mom-
# [465/653] https://blog.naver.com/sbang18
# [466/653] https://blog.naver.com/2020228
# [467/653] https://blog.naver.com/ella_holiday
# [468/653] https://blog.naver.com/9djaaj
# [469/653] https://blog.naver.com/youngch1127
# [470/653] https://blog.naver.com/dana-_
# [471/653] https://blog.naver.com/hkhkgreen
# [472/653] https://blog.naver.com/beyond0ne
# [473/653] https://blog.naver.com/chneyy
# [474/653] https://blog.naver.com/dbdnjsdl0208
# [475/653] https://blog.naver.com/layeonparkgogo/224033861706
# [476/653] https://blog.naver.com/yuldoing
# [477/653] https://blog.naver.com/formulog
# [478/653] https://blog.naver.com/just_do_it_bunny
# [479/653] https://blog.naver.com/18sunhong486
# [480/653] https://blog.naver.com/gkswldidi
# [481/653] https://blog.naver.com/kcoznk5
# [482/653] https://blog.naver.com/beauty_n_nail
# [483/653] https://blog.naver.com/rt_clair
# [484/653] https://blog.naver.com/kydonailstudio
# [485/653] https://blog.naver.com/19pongki
# [486/653] https://blog.naver.com/j_01_20
# [487/653] https://blog.naver.com/yomdaeji
# [488/653] https://blog.naver.com/emmamary
# [489/653] https://blog.naver.com/rhdwnsla5656
# [490/653] https://blog.naver.com/dudghk0325
# [491/653] https://blog.naver.com/gnlgus3616
# [492/653] https://blog.naver.com/oj6676/224047412461
# [493/653] https://blog.naver.com/areum_316
# [494/653] https://blog.naver.com/dreammongsil
# [495/653] https://blog.naver.com/jjennie-
# [496/653] https://blog.naver.com/nature6207
# [497/653] https://blog.naver.com/1-986
# [498/653] https://blog.naver.com/juneunri
# [499/653] https://blog.naver.com/kkk48770
# [500/653] https://blog.naver.com/dlaqudtnr120
# [501/653] https://blog.naver.com/cashewnut03
# [502/653] https://blog.naver.com/hjrang0606/224067002975
# [503/653] https://blog.naver.com/seodajung2
# [504/653] https://blog.naver.com/haruit-
# [505/653] https://blog.naver.com/eun0300
# [506/653] https://blog.naver.com/ehddnjsalwls
# [507/653] https://blog.naver.com/bunsigvip
# [508/653] https://blog.naver.com/honeyboney_
# [509/653] https://blog.naver.com/audrey2020
# [510/653] https://blog.naver.com/nailatti
# [511/653] https://blog.naver.com/thumbnail2021
# [512/653] https://blog.naver.com/f2mg1
# [513/653] https://blog.naver.com/ariel719
# [514/653] https://blog.naver.com/honeyboney_
# [515/653] https://blog.naver.com/tmfrlalcl
# [516/653] https://blog.naver.com/blackholecd/223733409343
# [517/653] https://blog.naver.com/neat_hy
# [518/653] https://blog.naver.com/dazzlerjj
# [519/653] https://blog.naver.com/dhoq
# [520/653] https://blog.naver.com/marinpa
# [521/653] https://blog.naver.com/64057o4p
# [522/653] https://blog.naver.com/mjydestiny/224028713982
# [523/653] https://blog.naver.com/daebakyo/223499549070
# [524/653] https://blog.naver.com/f2mg2
# [525/653] https://blog.naver.com/chneyy
# [526/653] https://blog.naver.com/gm8525
# [527/653] https://blog.naver.com/sumin0516
# [528/653] https://blog.naver.com/lqud/224033566632
# [529/653] https://blog.naver.com/mingminging_-
# [530/653] https://blog.naver.com/yoonjung_e
# [531/653] https://blog.naver.com/yeonjuu77
# [532/653] https://blog.naver.com/too_bins
# [533/653] https://blog.naver.com/pej8581
# [534/653] https://blog.naver.com/dltndus819
# [535/653] https://blog.naver.com/juvide
# [536/653] https://blog.naver.com/ksmember
# [537/653] https://blog.naver.com/insom-
# [538/653] https://blog.naver.com/sikhye0701/223020100177
# [539/653] https://blog.naver.com/chois909/224081066778
# [540/653] https://blog.naver.com/algus744
# [541/653] https://blog.naver.com/naheer
# [542/653] https://blog.naver.com/supia_heeya
# [543/653] https://blog.naver.com/kim_toggi
# [544/653] https://blog.naver.com/melrosequeen
# [545/653] https://blog.naver.com/lcejetty
# [546/653] https://blog.naver.com/spotlog
# [547/653] https://blog.naver.com/jinah0213
# [548/653] https://blog.naver.com/hxxya
# [549/653] https://blog.naver.com/fairyviolet/224066762337
# [550/653] https://blog.naver.com/laumi22
# [551/653] https://blog.naver.com/machyaki
# [552/653] https://blog.naver.com/yu-ri
# [553/653] https://blog.naver.com/2885295
# [554/653] https://blog.naver.com/1003wlstlf
# [555/653] https://blog.naver.com/pih870318/224070988316
# [556/653] https://blog.naver.com/tas4924
# [557/653] https://blog.naver.com/mits37
# [558/653] https://blog.naver.com/yoon_1014
# [559/653] https://blog.naver.com/rlawlgo85
# [560/653] https://blog.naver.com/colorful_since2014
# [561/653] https://blog.naver.com/seulillililiiiilill
# [562/653] https://blog.naver.com/rkswlwoddl84
# [563/653] https://blog.naver.com/viviankk
# [564/653] https://blog.naver.com/leehjl
# [565/653] https://blog.naver.com/windywitch
# [566/653] https://blog.naver.com/failoveit
# [567/653] https://blog.naver.com/mhub2373
# [568/653] https://blog.naver.com/eggi33
# [569/653] https://blog.naver.com/4zctfywg
# [570/653] https://blog.naver.com/makeupchae_
# [571/653] https://blog.naver.com/qhfka4964
# [572/653] https://blog.naver.com/j75ty006
# [573/653] https://blog.naver.com/angelasong0814/224037404949
# [574/653] https://blog.naver.com/owner6161
# [575/653] https://blog.naver.com/njuiwwik/223993701891
# [576/653] https://blog.naver.com/gpdnjs5278
# [577/653] https://blog.naver.com/dbsgml1324
# [578/653] https://blog.naver.com/knsan_1
# [579/653] https://blog.naver.com/yej200628
# [580/653] https://blog.naver.com/low141251
# [581/653] https://blog.naver.com/qw9mby8r
# [582/653] https://blog.naver.com/bllong2/223908489127
# [583/653] https://blog.naver.com/yulim0306
# [584/653] https://blog.naver.com/vinmongz
# [585/653] https://blog.naver.com/labrow_nail
# [586/653] https://blog.naver.com/ryumiryumi_
# [587/653] https://blog.naver.com/kikiyaa
# [588/653] https://blog.naver.com/hisgoddess
# [589/653] https://blog.naver.com/yeongyeong2322
# [590/653] https://blog.naver.com/ttuleu
# [591/653] https://blog.naver.com/huhssuu1105
# [592/653] https://blog.naver.com/beautyna8113
# [593/653] https://blog.naver.com/jyjs0430
# [594/653] https://blog.naver.com/iambeautylove
# [595/653] https://blog.naver.com/nailofdemain
# [596/653] https://blog.naver.com/sasapo
# [597/653] https://blog.naver.com/dashube
# [598/653] https://blog.naver.com/color_g_beauty
# [599/653] https://blog.naver.com/jinyk4735
# [600/653] https://blog.naver.com/ju2qpm68
# [601/653] https://blog.naver.com/ssong5219
# [602/653] https://blog.naver.com/reality2024
# [603/653] https://blog.naver.com/leegun0917
# [604/653] https://blog.naver.com/hadarui
# [605/653] https://blog.naver.com/mini_kkobugi
# [606/653] https://blog.naver.com/lhjmario
# [607/653] https://blog.naver.com/roalove20
# [608/653] https://blog.naver.com/sujinyaejin
# [609/653] https://blog.naver.com/ccccccho_v/224070389937
# [610/653] https://blog.naver.com/next25
# [611/653] https://blog.naver.com/layeonparkgogo/224080311552
# [612/653] https://blog.naver.com/nezytable
# [613/653] https://blog.naver.com/mini7254
# [614/653] https://blog.naver.com/extraordinary5873
# [615/653] https://blog.naver.com/hshee069
# [616/653] https://blog.naver.com/shobee_
# [617/653] https://blog.naver.com/yoojoo25
# [618/653] https://blog.naver.com/j02nara
# [619/653] https://blog.naver.com/chavely85/222920805508
# [620/653] https://blog.naver.com/lsmfm0722/224078489110
# [621/653] https://blog.naver.com/minivlog_
# [622/653] https://blog.naver.com/frendlylucks
# [623/653] https://blog.naver.com/hebbeum
# [624/653] https://blog.naver.com/kso21111
# [625/653] https://blog.naver.com/chaesta-
# [626/653] https://blog.naver.com/tghyujki245
# [627/653] https://blog.naver.com/thswl3
# [628/653] https://blog.naver.com/neuljh
# [629/653] https://blog.naver.com/psy4990
# [630/653] https://blog.naver.com/won_jieun
# [631/653] https://blog.naver.com/shnaaz
# [632/653] https://blog.naver.com/sehyangg
# [633/653] https://blog.naver.com/purity_chloe
# [634/653] https://blog.naver.com/characfter14144
# [635/653] https://blog.naver.com/mydbfla33
# [636/653] https://blog.naver.com/gpwl4483
# [637/653] https://blog.naver.com/yeorum5
# [638/653] https://blog.naver.com/ella_holiday
# [639/653] https://blog.naver.com/zarzayo
# [640/653] https://blog.naver.com/honey-rin/224077713656
# [641/653] https://blog.naver.com/hiwoo4443
# [642/653] https://blog.naver.com/lsm31029
# [643/653] https://blog.naver.com/redgusl20
# [644/653] https://blog.naver.com/suzin___
# [645/653] https://blog.naver.com/nadozoa_
# [646/653] https://blog.naver.com/electronic
# [647/653] https://blog.naver.com/wodms10
# [648/653] https://blog.naver.com/dankelife
# [649/653] https://blog.naver.com/heoutn5037
# [650/653] https://blog.naver.com/pluchke_korea
# [651/653] https://blog.naver.com/cotton_hotplace
# [652/653] https://blog.naver.com/wonish_s2
# [653/653] https://blog.naver.com/jhjh3123

# %% [markdown]
# ### CSV 저장

# %%
if IS_SAVE_CSV:
    os.makedirs(ROOT_DOWNLOAD_DIR, exist_ok=True)
    df_enriched.to_csv(CSV_PATH, index=False, encoding="utf-8-sig")
    print("CSV 저장 완료:", CSV_PATH)
# Out:
# CSV 저장 완료: craw-download-file\20251120_03_multi.csv

# %%
df_enriched
# Out:
#      idx search_keyword           writer                               title  \
# 0      0       짧은 손톱 네일      해오름달 하루, 수진  365일:데일리스토리, 해오름달 하루, 수진 : 네이버 블로그
# 1      1       짧은 손톱 네일        개복치의 일상생활                 개복치의 일상생활 : 네이버 블로그
# 2      2       짧은 손톱 네일         나는 부엉이✨️                  나는 부엉이✨️ : 네이버 블로그
# 3      3       짧은 손톱 네일             제이와이  검단 늘뷰티스튜디오 귀여운 짧은손톱 네일아트 : 네이버 블로그
# 4      4       짧은 손톱 네일       @hyo_kkang                @hyo_kkang : 네이버 블로그
# ..   ...            ...              ...                                 ...
# 648  648    손이 예뻐보이는 네일  행 복 한 기 록 ✿♥‿♥✿           행 복 한 기 록 ✿♥‿♥✿ : 네이버 블로그
# 649  649    손이 예뻐보이는 네일         ADORABLE                  ADORABLE : 네이버 블로그
# 650  650    손이 예뻐보이는 네일      유알, You are      *Daily*, 유알, You are : 네이버 블로그
# 651  651    손이 예뻐보이는 네일        SENIVERSE                 SENIVERSE : 네이버 블로그
# 652  652    손이 예뻐보이는 네일         조이하하 블로그                  조이하하 블로그 : 네이버 블로그
#
#                                                   text        date  \
# 0    한 달에 한 번 네일 바꾸고 싶을 때마다 생각나는 잠실역 네일아트 잘하는 곳 벨라네...  2025-11-06
# 1    연예인들은 짧은손톱도 넘 귀엽던데 내가하면 왠지 좀 뭉툭해보여...하는분들 짧은손톱...  2025-08-25
# 2    받을 수 있는 망원역 네일샵 <조이네일랜드> 꼬옥 방문해보세용 #마포네일샵 #홍대네...  2025-10-23
# 3    안녕하세요 제이와이예요 :-) 저번에 길었던 손톱을 싹 다듬고 이번에 짧은손톱 네일...  2025-07-23
# 4    논현역 짧은손톱 네일도 예쁘게 받을 수 있다는 소문에 완전 기대했어요 짧은 손톱도 ...  2025-09-20
# ..                                                 ...         ...
# 648  넓고 깔끔한 느낌을 주던 네일인무드 원장님도 친절하시고 편안하게 케어 해주셔서 넘 ...  2025-11-06
# 649  ✨ 진짜 '예쁜 손'은 네일 컬러가 예쁜 손이 아니라, 손톱이 부드럽고 매끄러운 손...  2025-10-17
# 650  혹시 관심있으신 분들이 있으실까봐ㅎㅎ 네일 후기 이번엔 완전 새로운 가을 디자인 네...  2025-11-13
# 651  저는 파츠가 잔뜩 붙은 화려한 네일보다는, 은은하게 예뻐 보이는 청순한 디자인이 훨...  2025-10-30
# 652  사진으로 봤던 샘플 그 이상으로 고급스럽고 손이 예뻐 보이는 디자인이 너무 많았어요...  2025-11-16
#
#                                                link  \
# 0                   https://blog.naver.com/suzin___
# 1                 https://blog.naver.com/realblue88
# 2                 https://blog.naver.com/boo______1
# 3    https://blog.naver.com/sunkjydbgn/223944212796
# 4              https://blog.naver.com/remember_0629
# ..                                              ...
# 648               https://blog.naver.com/heoutn5037
# 649            https://blog.naver.com/pluchke_korea
# 650          https://blog.naver.com/cotton_hotplace
# 651                https://blog.naver.com/wonish_s2
# 652                 https://blog.naver.com/jhjh3123
#
#                                              full_text  image_count
# 0    \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...            0
# 1    \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...            0
# 2    \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...            0
# 3    \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...            0
# 4    \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...            0
# ..                                                 ...          ...
# 648  \n\n\n\n\n\n\n\n\n\n\n\n\n드림아트 프리미엄 미술세트 6세아이 ...            0
# 649  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...            0
# 650  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...            0
# 651  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...            0
# 652  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...            0
#
# [653 rows x 9 columns]
