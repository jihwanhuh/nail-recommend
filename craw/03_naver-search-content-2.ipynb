# %% [markdown]
# # 네이버 검색 + 블로그 본문 스크랩

# %% [markdown]
# ## 정보 입력 / 전역 설정

# %% [markdown]
# ### 환경 변수

# %%
# 실행 순번 - 경로에 사용
RUN_INDEX = 2                 # !!중요!! - 실행=파일명 순번 => 수동 업데이트

# --- 검색 일자 ---
start_date = '20250101'
end_date = ''                 # 입력 안 하면 오늘 날짜로 세팅

# --- 스크롤 횟수 ---
scroll_times = 10              # 스크롤 횟수

# --- 다운로드 옵션 ---
IS_SAVE_CSV = True            # CSV(엑셀용) 저장 여부
IS_SAVE_IMAGES = False         # 이미지 저장 여부

# --- 파일 다운로드 경로 (ROOT) --
ROOT_DOWNLOAD_DIR = 'craw-download-file'

# %% [markdown]
# ### 검색 키워드 입력

# %%
# 단일 키워드
keyword = '네일추천'            # 검색 키워드
search_keyword = keyword      # 검색창에 넣을 실제 값

# 다중 키워드 (여러번 검색 수행) - 비어 있다면, 단일 키워드로 수행
search_keywords = [
    # # 1) 기본/일반 네일 (베이스 분포용)
    # "네일 추천",
    # "네일 디자인",
    # "셀프네일 디자인",
    # "데일리 네일",
    # "직장인 네일",

    # 2) 쉐입 중심
    "라운드 네일 디자인",
    "오벌 네일 디자인",
    "스퀘어 네일 디자인",
    "스퀘어오벌 네일",
    "아몬드 네일 디자인",

    # 3) 길이·손 특징 중심
    # "짧은 손톱 네일",
    # "짧은손톱 셀프네일",
    # "긴 손톱 네일",
    # "손가락 길어보이는 네일",
    # "손이 예뻐보이는 네일",
]

# %% [markdown]
# ## 함수 정의

# %% [markdown]
# ### 모듈 import

# %%
import os
import re
import requests
from datetime import datetime
from urllib.parse import urljoin

import pandas as pd
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
import mimetypes

# %% [markdown]
# ### 파일 경로

# %%
## 파일 경로 : 일자 + 실행 순번 + 검색어 or multi

today_date = datetime.now().strftime("%Y%m%d")

def sanitize_keyword(kw: str) -> str:
    """파일/폴더명으로 쓸 수 있게 키워드 정제 """
    if not isinstance(kw, str):
        kw = str(kw)
    kw = kw.strip().strip('"').strip("'")
    # 파일명에 쓸 수 없는 문자 제거
    kw = re.sub(r'[\\/:*?"<>|]', '_', kw)
    # 너무 길면 잘라내기
    if len(kw) == 0:
        kw = "keyword"
    return kw

### 단일/다중에 따라 파일명 기준 키워드 결정
if search_keywords:          # 다중 키워드 리스트가 비어있지 않다면
    base_keyword_for_path = "multi"
else:
    base_keyword_for_path = search_keyword

SAFE_KEYWORD = sanitize_keyword(base_keyword_for_path)

SUB_NAME = f"{today_date}_{RUN_INDEX:02d}_{SAFE_KEYWORD}"

CSV_PATH = os.path.join(ROOT_DOWNLOAD_DIR, f"{SUB_NAME}.csv")
IMAGE_DIR = os.path.join(ROOT_DOWNLOAD_DIR, SUB_NAME)

# %% [markdown]
# ### 날짜 정규화

# %%
import re
from datetime import datetime, timedelta, timezone

KST = timezone(timedelta(hours=9))

_abs = re.compile(r"^\s*(\d{4})\.(\d{1,2})\.(\d{1,2})\.?\s*$")
_m  = re.compile(r"(\d+)\s*분\s*전")
_h  = re.compile(r"(\d+)\s*시간\s*전")
_d  = re.compile(r"(\d+)\s*일\s*전")
_w  = re.compile(r"(\d+)\s*주\s*전")
_not_date_tail = re.compile(r"(?:단|TOP),\s*$")        # 예: "A34면 1단," , "A30면 TOP,"

def _ymd(dt: datetime) -> str:
    # Python/Excel 공통 인식 포맷: YYYY-MM-DD
    return f"{dt.year:04d}-{dt.month:02d}-{dt.day:02d}"

def normalize_news_date(texts, now: datetime | None = None) -> str | None:
    # 변환 실패 대비: 원본 첫 값 보관
    original_first = texts if isinstance(texts, str) else (texts[0] if texts else None)

    if isinstance(texts, str):
        texts = [texts]
    now = now or datetime.now(KST)

    for t in texts:
        if not t:
            continue
        s = t.strip()

        # 지면/면·단, TOP 꼬리면 스킵
        if _not_date_tail.search(s):
            continue

        # 절대형
        m = _abs.match(s)
        if m:
            y, mo, d = map(int, m.groups())
            return f"{y:04d}-{mo:02d}-{d:02d}"

        # 상대형
        if (mm := _h.search(s)): # 분
            return _ymd(now - timedelta(minutes=int(mm.group(1))))
        if (mh := _h.search(s)): # 시간
            return _ymd(now - timedelta(hours=int(mh.group(1))))
        if (md := _d.search(s)): # 일
            return _ymd(now - timedelta(days=int(md.group(1))))
        if (mw := _w.search(s)): # 주
            return _ymd(now - timedelta(weeks=int(mw.group(1))))

    # 날짜형 변환이 안되면 첫 번째 값 반환
    return original_first

# %% [markdown]
# ### 검색 결과 카드 한 개에서 정보 추출

# %%
def get_content(review):
    condic = {}

    title_css  = (
        "span.sds-comps-text.sds-comps-text-ellipsis.sds-comps-text-ellipsis-1"
        ".sds-comps-text-type-headline1.sds-comps-text-weight-sm"
    )
    text_css   = (
        "span.sds-comps-text-type-body1"
    )
    viewer_css = (
        "div.sds-comps-horizontal-layout.sds-comps-inline-layout"
        ".sds-comps-profile-info-title"
    )
    date_css   = (
        "span.sds-comps-text.sds-comps-text-type-body2"
        ".sds-comps-text-weight-sm.sds-comps-profile-info-subtext"
    )
    link_css   = 'a[href*="blog.naver.com"]'

    condic['writer'] = review.find_element(By.CSS_SELECTOR, viewer_css) \
                             .get_attribute('innerText').strip()
    condic['title'] = review.find_element(By.CSS_SELECTOR, title_css) \
                             .get_attribute('innerText').strip()
    condic['text'] = review.find_element(By.CSS_SELECTOR, text_css) \
                            .get_attribute('innerText').strip()
    condic['date'] = normalize_news_date(
        review.find_element(By.CSS_SELECTOR, date_css)
              .get_attribute('innerText').strip()
    )
    try:
        condic['link'] = review.find_element(By.CSS_SELECTOR, link_css) \
                                .get_attribute('href')
    except Exception:
        condic['link'] = ''
        print(f"condic['link'] -> 추출오류 : {condic['title']}")

    return condic

# %% [markdown]
# ### 블로그 본문 크롤링 + 이미지 저장

# %%
def crawl_blog_content(url: str, search_idx: int,
                       image_dir: str,
                       is_download_images: bool = True):

    COMMON_HEADERS = {"User-Agent": "Mozilla/5.0"}

    resp = requests.get(url, headers=COMMON_HEADERS)
    resp.raise_for_status()
    soup = BeautifulSoup(resp.text, "html.parser")

    # iframe 찾기
    iframe = soup.select_one("iframe#mainFrame")
    if iframe is None:
        for f in soup.find_all("iframe"):
            src = f.get("src") or ""
            if "PostView" in src:
                iframe = f
                break

    if iframe is None:
        print(f"[WARN] iframe 없음 → {url}")
        return {"title": "", "full_text": "", "image_count": 0}

    inner_src = iframe.get("src")
    inner_url = urljoin(resp.url, inner_src)

    # iframe 안쪽 요청
    resp2 = requests.get(inner_url, headers=COMMON_HEADERS)
    resp2.raise_for_status()
    soup2 = BeautifulSoup(resp2.text, "html.parser")

    # 제목
    title_tag = soup2.find("title")
    title = title_tag.get_text(strip=True) if title_tag else ""

    # 본문 텍스트
    paragraphs = [p.get_text(" ", strip=True) for p in soup2.find_all("p")]
    full_text = "\n".join(paragraphs)

    if not full_text.strip():
        main_div = soup2.select_one("div.se-main-container")
        if main_div:
            paragraphs = [
                p.get_text(" ", strip=True)
                for p in main_div.find_all(["p", "span"])
            ]
            full_text = "\n".join(paragraphs)

    # 이미지 다운로드
    image_count = 0
    if is_download_images:
        content = (
            soup2.select_one("div.se-main-container")
            or soup2.select_one("#postViewArea")
            or soup2
        )
        img_tags = content.find_all("img")

        os.makedirs(image_dir, exist_ok=True)

        allowed_hosts = ("postfiles.pstatic.net", "blogfiles.pstatic.net")

        for img_idx, img in enumerate(img_tags, start=1):
            src = img.get("data-origin") or img.get("data-src") or img.get("src")
            if not src:
                continue

            if not any(h in src for h in allowed_hosts):
                continue

            if src.startswith("//"):
                src = "https:" + src
            elif src.startswith("/"):
                src = urljoin(inner_url, src)
            if src.startswith("data:"):
                continue

            hi_src = src
            if "type=w80_blur" in src:
                hi_src = src.replace("type=w80_blur", "type=w966")

            img_headers = {
                "User-Agent": "Mozilla/5.0",
                "Referer": inner_url,
            }

            img_resp = None
            for candidate in [hi_src, src]:
                try:
                    r = requests.get(candidate, headers=img_headers, timeout=10)
                    r.raise_for_status()
                    img_resp = r
                    break
                except Exception:
                    img_resp = None

            if img_resp is None:
                continue

            content_type = img_resp.headers.get("Content-Type", "")
            if "image" not in content_type:
                continue

            if not is_download_images:
                image_count += 1
                continue

            ext = mimetypes.guess_extension(content_type.split(";")[0]) or ".jpg"

            # IMG_{검색결과순번 4자리}_{본문내 이미지순번 4자리}
            filename = os.path.join(
                image_dir,
                f"IMG_{search_idx:04d}_{img_idx:04d}{ext}"
            )

            with open(filename, "wb") as f:
                f.write(img_resp.content)

            image_count += 1

    return {
        "title": title,
        "full_text": full_text,
        "image_count": image_count,
    }


def enrich_with_blog_contents(df_search: pd.DataFrame) -> pd.DataFrame:
    """
    1번 검색 df 기준:
    - title 덮어쓰기 (블로그 실제 제목)
    - full_text 열 추가
    - image_count 열 추가
    """

    df = df_search.copy()
    df["full_text"] = ""
    df["image_count"] = 0

    for idx, row in df.iterrows():
        url = row.get("link", "")
        if not isinstance(url, str) or not url.strip():
            continue

        search_idx = idx + 1
        print(f"[{search_idx}/{len(df)}] {url}")

        info = crawl_blog_content(
            url=url,
            search_idx=search_idx,
            image_dir=IMAGE_DIR,
            is_download_images=IS_SAVE_IMAGES
        )

        df.at[idx, "title"] = info["title"]
        df.at[idx, "full_text"] = info["full_text"]
        df.at[idx, "image_count"] = info["image_count"]

    return df

# %% [markdown]
# ## 실행부

# %% [markdown]
# ### 검색 페이지 로드 / 스크롤 / 본문 스크랩

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from urllib.parse import quote_plus

from time import sleep
import random

def encode_keyword(search_keyword: str) -> str:
    return quote_plus(search_keyword)

driver = webdriver.Chrome()

# 다중 키워드가 있으면 그걸 사용, 없으면 단일 search_keyword 사용
if search_keywords:
    keywords_to_run = search_keywords
else:
    keywords_to_run = [search_keyword]

all_results = []

for q in keywords_to_run:
    print(f"\n=== 검색 시작: {q} ===")
    enc_q = encode_keyword(q)

    url = (
        "https://search.naver.com/search.naver"
        "?ssc=tab.blog.all"
        "&sm=tab_opt"
        "&where=blog"
        f"&query={enc_q}"
        f"&nso=so%3Ar%2Cp%3Afrom{start_date}to{end_date}"
    )

    driver.get(url)

    # 스크롤
    xp = '/html'
    review_box = driver.find_element(By.XPATH, xp)

    for _ in range(scroll_times):
        driver.execute_script('arguments[0].scrollTop = arguments[0].scrollHeight', review_box)
        sleep(random.randint(2, 3))

    # 박스 선택
    forms = driver.find_elements(
        By.CSS_SELECTOR,
        'div.sds-comps-vertical-layout.sds-comps-full-layout.YNThgbNOBFUb3Wc2Cq47'
    )
    print('박스 수 :', len(forms))

    # 카드별 정보 수집
    success = 0
    # fail_stats = {}
    for i, form in enumerate(forms, start=1):
        try:
            dic = get_content(form)
            dic["search_keyword"] = q   # 어떤 검색어에서 나온 결과인지 기록
            all_results.append(dic)
            success += 1
        except Exception as e:
            name = type(e).__name__
            # fail_stats[name] = fail_stats.get(name, 0) + 1
            # print(f"[{q}] 카드 {i}/{len(forms)} skip → {name}: {e}")

    # print(f"[{q}] 성공: {success} / {len(forms)}")
    # print(f"[{q}] 실패 통계: {fail_stats}")

# 모든 결과를 하나의 DataFrame으로
df_search = pd.DataFrame(all_results)
print("총 수집 건수:", len(df_search))


df_search['idx'] = range(len(df_search))

cols = (['idx', 'search_keyword']
        + [c for c in df_search.columns if c not in ['idx', 'search_keyword']])
df_search = df_search[cols]

df_search.head()
# Out:
# === 검색 시작: 라운드 네일 디자인 ===
# 박스 수 : 138
#
# === 검색 시작: 오벌 네일 디자인 ===
# 박스 수 : 133
#
# === 검색 시작: 스퀘어 네일 디자인 ===
# 박스 수 : 138
#
# === 검색 시작: 스퀘어오벌 네일 ===
# 박스 수 : 140
#
# === 검색 시작: 아몬드 네일 디자인 ===
# 박스 수 : 130
# 총 수집 건수: 679
#    idx search_keyword     writer                                title  \
# 0    0     라운드 네일 디자인       지하세계     부산 명지 네일샵 휘게네일스튜디오 스퀘어라운드 자석젤 후기
# 1    1     라운드 네일 디자인    마르크의 여운      라운드네일에 어울리는 다양한 디자인 스타일 10가지 소개
# 2    2     라운드 네일 디자인      27분 전     성수네일 성수동 깔끔한 라운드 파츠 네일 네일포시즌 성수점
# 3    3     라운드 네일 디자인  프로기의 소소살이  등촌역 네일샵 추천 • 라운드네일 젤페디 내성발톱 재생관리 후기
# 4    4     라운드 네일 디자인     중성 부르델     라운드네일 관리 방법 집에서 쉽게 아름답게 가꾸는 법 안내
#
#                                                 text        date  \
# 0  네일 쉐입 종류와 선택 손톱 모양은 사실 어떤 걸로 할까 고민을 하다가 원래 모양이...  2025-05-09
# 1  이런 다양한 요소들 덕분에 라운드네일은 단순한 네일 디자인을 넘어, 많은 사람들에게...  2025-10-23
# 2  성수동 네일 네일포시즌 성수점 성수네일 성수동 깔끔한 라운드 파츠 네일 네일포시즌 ...  2025-11-14
# 3  일반젤 말고 자석젤은 처음 해봤는데 왜 이제 했나 싶을 정도로 만족도 200% 사진...  2025-07-18
# 4  다양한 디자인과 조화 라운드네일은 다양한 디자인과 잘 어울립니다 애니메이션 캐릭터,...  2025-11-16
#
#                                      link
# 0      https://blog.naver.com/ochawonjiha
# 1        https://blog.naver.com/flaw52153
# 2  https://blog.naver.com/flowerforseason
# 3      https://blog.naver.com/in_greenery
# 4        https://blog.naver.com/which4288

# %% [markdown]
# ### 블로그 본문 + 이미지 수집

# %%
### 블로그 본문 + 이미지 수집
if IS_SAVE_IMAGES or True :   # 이미지 저장 안하더라도 본문 수집은 수행
    df_enriched = enrich_with_blog_contents(df_search)
else:
    df_enriched = df_search.copy()
# Out:
# [1/679] https://blog.naver.com/ochawonjiha
# [2/679] https://blog.naver.com/flaw52153
# [3/679] https://blog.naver.com/flowerforseason
# [4/679] https://blog.naver.com/in_greenery
# [5/679] https://blog.naver.com/which4288
# [6/679] https://blog.naver.com/gowood701
# [7/679] https://blog.naver.com/gold77com
# [8/679] https://blog.naver.com/dms8001
# [9/679] https://blog.naver.com/joojoo7400
# [10/679] https://blog.naver.com/thick7035
# [11/679] https://blog.naver.com/twomatches
# [12/679] https://blog.naver.com/blackholecd/224054854209
# [13/679] https://blog.naver.com/har0913
# [14/679] https://blog.naver.com/dhrpdyd60510
# [15/679] https://blog.naver.com/nagi96/224047204051
# [16/679] https://blog.naver.com/sexyguy30241
# [17/679] https://blog.naver.com/goodse7/224016577458
# [18/679] https://blog.naver.com/hahoitar
# [19/679] https://blog.naver.com/pppmh0827/223967600257
# [20/679] https://blog.naver.com/kim-to-ki
# [21/679] https://blog.naver.com/m_a_u_
# [22/679] https://blog.naver.com/lomvely
# [23/679] https://blog.naver.com/diecruel/223988805958
# [24/679] https://blog.naver.com/sl7856
# [25/679] https://blog.naver.com/weareopen
# [26/679] https://blog.naver.com/wing3527
# [27/679] https://blog.naver.com/ksmember
# [28/679] https://blog.naver.com/zldnld99/223687200461
# [29/679] https://blog.naver.com/hnoni863
# [30/679] https://blog.naver.com/smallpeacock625
# [31/679] https://blog.naver.com/zin1218
# [32/679] https://blog.naver.com/travelday
# [33/679] https://blog.naver.com/minimouse24/223860687901
# [34/679] https://blog.naver.com/rrsnow/224068854021
# [35/679] https://blog.naver.com/aeri2884
# [36/679] https://blog.naver.com/as06123
# [37/679] https://blog.naver.com/codus4592
# [38/679] https://blog.naver.com/happy_prayer
# [39/679] https://blog.naver.com/calm_and_peace
# [40/679] https://blog.naver.com/serabull
# [41/679] https://blog.naver.com/choiseou
# [42/679] https://blog.naver.com/redsea2905
# [43/679] https://blog.naver.com/aboutcheny
# [44/679] https://blog.naver.com/or____________/224065325666
# [45/679] https://blog.naver.com/arashi310
# [46/679] https://blog.naver.com/jetchoi
# [47/679] https://blog.naver.com/dmswn2683
# [48/679] https://blog.naver.com/ohhhm
# [49/679] https://blog.naver.com/min_story_
# [50/679] https://blog.naver.com/wjuzi
# [51/679] https://blog.naver.com/fcchh7023
# [52/679] https://blog.naver.com/greta0074
# [53/679] https://blog.naver.com/liziah
# [54/679] https://blog.naver.com/yjk_0105
# [55/679] https://blog.naver.com/zz_0_zz
# [56/679] https://blog.naver.com/gobbu13
# [57/679] https://blog.naver.com/eb3522
# [58/679] https://blog.naver.com/aobo7
# [59/679] https://blog.naver.com/cosreader/223717672913
# [60/679] https://blog.naver.com/lovelyelice/224041958707
# [61/679] https://blog.naver.com/lovelyelice/224041958707
# [62/679] https://blog.naver.com/smy2166/224037464864
# [63/679] https://blog.naver.com/rlawlgo85
# [64/679] https://blog.naver.com/daebakyo/223790011913
# [65/679] https://blog.naver.com/greenjbee/223663324281
# [66/679] https://blog.naver.com/lucia_1010
# [67/679] https://blog.naver.com/loverasi
# [68/679] https://blog.naver.com/bbekimha/223794517853
# [69/679] https://blog.naver.com/dbsghtlsdo
# [70/679] https://blog.naver.com/misspp78
# [71/679] https://blog.naver.com/newze_/223981619614
# [72/679] https://blog.naver.com/windywitch
# [73/679] https://blog.naver.com/dony_zzang/224009326350
# [74/679] https://blog.naver.com/andoo7/223844881313
# [75/679] https://blog.naver.com/jina199
# [76/679] https://blog.naver.com/yunji678
# [77/679] https://blog.naver.com/gkgntkd34630
# [78/679] https://blog.naver.com/hongzzang18
# [79/679] https://blog.naver.com/gguks_nayomi
# [80/679] https://blog.naver.com/qufqlc08/224080111262
# [81/679] https://blog.naver.com/jungeun9019/224069433927
# [82/679] https://blog.naver.com/u1tanning
# [83/679] https://blog.naver.com/ekgp1356
# [84/679] https://blog.naver.com/mukdduki
# [85/679] https://blog.naver.com/hi_sat
# [86/679] https://blog.naver.com/yoni_0905/223992830985
# [87/679] https://blog.naver.com/yhluna0228
# [88/679] https://blog.naver.com/pinkjinjoo/224066252874
# [89/679] https://blog.naver.com/18sunhong486
# [90/679] https://blog.naver.com/chuuu_j
# [91/679] https://blog.naver.com/dailychuuu
# [92/679] https://blog.naver.com/ccccccho_v/224070389937
# [93/679] https://blog.naver.com/ryunni629
# [94/679] https://blog.naver.com/gydel4856
# [95/679] https://blog.naver.com/fear3330
# [96/679] https://blog.naver.com/seelee7830
# [97/679] https://blog.naver.com/tohyun4740
# [98/679] https://blog.naver.com/singlesmagazine/224071278544
# [99/679] https://blog.naver.com/likeplum5
# [100/679] https://blog.naver.com/formulog
# [101/679] https://blog.naver.com/iambeautylove
# [102/679] https://blog.naver.com/seul_gei
# [103/679] https://blog.naver.com/yi__jj
# [104/679] https://blog.naver.com/yuha220222
# [105/679] https://blog.naver.com/jsjjsj8
# [106/679] https://blog.naver.com/alizee8
# [107/679] https://blog.naver.com/pepekjin/224061290795
# [108/679] https://blog.naver.com/hnluv1004
# [109/679] https://blog.naver.com/didoo_ya
# [110/679] https://blog.naver.com/sinabronail
# [111/679] https://blog.naver.com/92_10_13
# [112/679] https://blog.naver.com/beaurosa
# [113/679] https://blog.naver.com/layeonparkgogo/223976639883
# [114/679] https://blog.naver.com/dbdiary
# [115/679] https://blog.naver.com/alal7667
# [116/679] https://blog.naver.com/xxhennixx
# [117/679] https://blog.naver.com/hijenna2
# [118/679] https://blog.naver.com/jsk8615/223948953117
# [119/679] https://blog.naver.com/levely3294/223962843553
# [120/679] https://blog.naver.com/roomy_atelier
# [121/679] https://blog.naver.com/ekdusld910111/223973668330
# [122/679] https://blog.naver.com/fiat710/224055318976
# [123/679] https://blog.naver.com/haejinryu
# [124/679] https://blog.naver.com/bllong2/224000375654
# [125/679] https://blog.naver.com/yangllll/224054950307
# [126/679] https://blog.naver.com/heeyeon1988/224009887012
# [127/679] https://blog.naver.com/watasiwapa
# [128/679] https://blog.naver.com/zwoos
# [129/679] https://blog.naver.com/dadamon330
# [130/679] https://blog.naver.com/nobleliz_
# [131/679] https://blog.naver.com/totalbeauty_bio
# [132/679] https://blog.naver.com/ddodong1224
# [133/679] https://blog.naver.com/maryje
# [134/679] https://blog.naver.com/nail_younglong
# [135/679] https://blog.naver.com/thumbnail2021
# [136/679] https://blog.naver.com/aortjfdl
# [137/679] https://blog.naver.com/ojs419
# [138/679] https://blog.naver.com/imun12
# [139/679] https://blog.naver.com/kiddy28/223594030427
# [140/679] https://blog.naver.com/rhdiddl652
# [141/679] https://blog.naver.com/luy85
# [142/679] https://blog.naver.com/wfjgygc862m5
# [143/679] https://blog.naver.com/gorgeous9673
# [144/679] https://blog.naver.com/qkrtmdcjftpsxja
# [145/679] https://blog.naver.com/skirt11927
# [146/679] https://blog.naver.com/heex0726
# [147/679] https://blog.naver.com/calm71349
# [148/679] https://blog.naver.com/assist6587
# [149/679] https://blog.naver.com/aobo7
# [150/679] https://blog.naver.com/restart0727
# [151/679] https://blog.naver.com/strong14659
# [152/679] https://blog.naver.com/yunji678
# [153/679] https://blog.naver.com/beautybitebyyeonsoo
# [154/679] https://blog.naver.com/hanbitnuri/222916009356
# [155/679] https://blog.naver.com/uhwa_beauty/222863225962
# [156/679] https://blog.naver.com/luci_yaaa/222947436643
# [157/679] https://blog.naver.com/sooy110/222720962975
# [158/679] https://blog.naver.com/ym9240/222874896306
# [159/679] https://blog.naver.com/oircmaziy6727
# [160/679] https://blog.naver.com/lqud/224025181574
# [161/679] https://blog.naver.com/lovely80popo
# [162/679] https://blog.naver.com/ybvmhtsc91885n
# [163/679] https://blog.naver.com/cfs898
# [164/679] https://blog.naver.com/aboutcheny
# [165/679] https://blog.naver.com/minimouse24/223885056282
# [166/679] https://blog.naver.com/f2mg1
# [167/679] https://blog.naver.com/rlawlgo85
# [168/679] https://blog.naver.com/rohabeauty
# [169/679] https://blog.naver.com/pej8581
# [170/679] https://blog.naver.com/lifeofbliss/224017609313
# [171/679] https://blog.naver.com/mylovebina
# [172/679] https://blog.naver.com/lovenpeace_
# [173/679] https://blog.naver.com/ians211/223747752494
# [174/679] https://blog.naver.com/todrlclfm97
# [175/679] https://blog.naver.com/choejds
# [176/679] https://blog.naver.com/lovedmsal87
# [177/679] https://blog.naver.com/shining_sarah
# [178/679] https://blog.naver.com/molly32
# [179/679] https://blog.naver.com/ryuzfl
# [180/679] https://blog.naver.com/wing3527
# [181/679] https://blog.naver.com/sincity01
# [182/679] https://blog.naver.com/fallrain94
# [183/679] https://blog.naver.com/jjwjss
# [184/679] https://blog.naver.com/hanuri37
# [185/679] https://blog.naver.com/diawlk
# [186/679] https://blog.naver.com/cufspr
# [187/679] https://blog.naver.com/pgontisaa3950
# [188/679] https://blog.naver.com/dongdongza79/223335047402
# [189/679] https://blog.naver.com/tjqhdud1001
# [190/679] https://blog.naver.com/eszzang1011
# [191/679] https://blog.naver.com/qmfosej/223350552107
# [192/679] https://blog.naver.com/tjdbs0323/223371832994
# [193/679] https://blog.naver.com/wlgysnl23/222956565222
# [194/679] https://blog.naver.com/zzeom14/223259178439
# [195/679] https://blog.naver.com/pkikimyk
# [196/679] https://blog.naver.com/11299/223350049498
# [197/679] https://blog.naver.com/x1j5ym8r
# [198/679] https://blog.naver.com/iris_93_
# [199/679] https://blog.naver.com/ewfz3310982
# [200/679] https://blog.naver.com/btpp77
# [201/679] https://blog.naver.com/progress11937
# [202/679] https://blog.naver.com/alsrud99717
# [203/679] https://blog.naver.com/qufqlc08/224080111262
# [204/679] https://blog.naver.com/mini_kkobugi
# [205/679] https://blog.naver.com/sweetdreama/222736301328
# [206/679] https://blog.naver.com/18sunhong486
# [207/679] https://blog.naver.com/gimunze
# [208/679] https://blog.naver.com/proseouler
# [209/679] https://blog.naver.com/singlesmagazine/224071278544
# [210/679] https://blog.naver.com/on_youth
# [211/679] https://blog.naver.com/mgle2294
# [212/679] https://blog.naver.com/amor0919
# [213/679] https://blog.naver.com/s_s82
# [214/679] https://blog.naver.com/dlaledma4915
# [215/679] https://blog.naver.com/happy_hworld/222796585992
# [216/679] https://blog.naver.com/pepekjin/224061290795
# [217/679] https://blog.naver.com/jsjjsj8
# [218/679] https://blog.naver.com/nobleliz_
# [219/679] https://blog.naver.com/jungeun9019/223988922261
# [220/679] https://blog.naver.com/sbs-6218600
# [221/679] https://blog.naver.com/e_h95
# [222/679] https://blog.naver.com/twinkle_mina/223906496430
# [223/679] https://blog.naver.com/dwg1016
# [224/679] https://blog.naver.com/thumbnail2021
# [225/679] https://blog.naver.com/daisy-3396
# [226/679] https://blog.naver.com/haejinryu
# [227/679] https://blog.naver.com/layeonparkgogo/223955856710
# [228/679] https://blog.naver.com/lovedarl2/223985769700
# [229/679] https://blog.naver.com/mongout_official
# [230/679] https://blog.naver.com/djoin50102
# [231/679] https://blog.naver.com/alldaybunny/222727921550
# [232/679] https://blog.naver.com/erqrfbvfo
# [233/679] https://blog.naver.com/ccwonju-11
# [234/679] https://blog.naver.com/soyosoyo01/224060100571
# [235/679] https://blog.naver.com/kes434/223926234036
# [236/679] https://blog.naver.com/aggieku0201/222724068460
# [237/679] https://blog.naver.com/momentofmiracle1017/223944627488
# [238/679] https://blog.naver.com/cjswo4354/223923152479
# [239/679] https://blog.naver.com/bakgeunah02
# [240/679] https://blog.naver.com/yoolim0224na
# [241/679] https://blog.naver.com/bllong2/223908489127
# [242/679] https://blog.naver.com/chungdam_jini/224050129782
# [243/679] https://blog.naver.com/namcheol223
# [244/679] https://blog.naver.com/lucidamuseum
# [245/679] https://blog.naver.com/5gguggu__
# [246/679] https://blog.naver.com/bettermom_hani
# [247/679] https://blog.naver.com/alal7667
# [248/679] https://blog.naver.com/ekgp1356
# [249/679] https://blog.naver.com/donggle0329
# [250/679] https://blog.naver.com/johappy129
# [251/679] https://blog.naver.com/thyroid67438
# [252/679] https://blog.naver.com/mmins-0610/223001981287
# [253/679] https://blog.naver.com/ssorish
# [254/679] https://blog.naver.com/yooj228
# [255/679] https://blog.naver.com/zzzopq123
# [256/679] https://blog.naver.com/cmbeauty-campusmento
# [257/679] https://blog.naver.com/euntill
# [258/679] https://blog.naver.com/cocolily13
# [259/679] https://blog.naver.com/onj0808/224064322318
# [260/679] https://blog.naver.com/daybyday-mayday
# [261/679] https://blog.naver.com/gaeulakio
# [262/679] https://blog.naver.com/rehoboth_lab
# [263/679] https://blog.naver.com/eul683486
# [264/679] https://blog.naver.com/dailynlog
# [265/679] https://blog.naver.com/daily_soli
# [266/679] https://blog.naver.com/iambeautylove
# [267/679] https://blog.naver.com/o323021
# [268/679] https://blog.naver.com/hullang_
# [269/679] https://blog.naver.com/llqg9k4p
# [270/679] https://blog.naver.com/zvxzuotj
# [271/679] https://blog.naver.com/mi2000oeo
# [272/679] https://blog.naver.com/m_a_u_
# [273/679] https://blog.naver.com/mkk1830
# [274/679] https://blog.naver.com/eunj3690
# [275/679] https://blog.naver.com/lkhlove8282
# [276/679] https://blog.naver.com/lunasally
# [277/679] https://blog.naver.com/wotup
# [278/679] https://blog.naver.com/ochawonjiha
# [279/679] https://blog.naver.com/h__meii
# [280/679] https://blog.naver.com/wing3527
# [281/679] https://blog.naver.com/sse411
# [282/679] https://blog.naver.com/yoongu0
# [283/679] https://blog.naver.com/10_e_dd
# [284/679] https://blog.naver.com/sohee_ty
# [285/679] https://blog.naver.com/siloam0191
# [286/679] https://blog.naver.com/moonsasang/224001852655
# [287/679] https://blog.naver.com/hestia89
# [288/679] https://blog.naver.com/jinnyframe
# [289/679] https://blog.naver.com/hnoni863
# [290/679] https://blog.naver.com/lina_review
# [291/679] https://blog.naver.com/har0913
# [292/679] https://blog.naver.com/blackholecd/224054854209
# [293/679] https://blog.naver.com/kyj5141
# [294/679] https://blog.naver.com/lqud/224025181574
# [295/679] https://blog.naver.com/hahoitar
# [296/679] https://blog.naver.com/goodse7/224016577458
# [297/679] https://blog.naver.com/mihraprc686
# [298/679] https://blog.naver.com/sweeti0714
# [299/679] https://blog.naver.com/weareopen
# [300/679] https://blog.naver.com/nagi96/224047204051
# [301/679] https://blog.naver.com/aobo7
# [302/679] https://blog.naver.com/kim-to-ki
# [303/679] https://blog.naver.com/4chi_27
# [304/679] https://blog.naver.com/buzzerrbeate/224079900799
# [305/679] https://blog.naver.com/art6014
# [306/679] https://blog.naver.com/leerang42
# [307/679] https://blog.naver.com/genzo13
# [308/679] https://blog.naver.com/diecruel/223988805958
# [309/679] https://blog.naver.com/flutistpark
# [310/679] https://blog.naver.com/coolhotsil
# [311/679] https://blog.naver.com/kkongdal2/222892564525
# [312/679] https://blog.naver.com/mycutegod/223184221319
# [313/679] https://blog.naver.com/gkfks26
# [314/679] https://blog.naver.com/arashi310
# [315/679] https://blog.naver.com/sm1004ys/222852325493
# [316/679] https://blog.naver.com/sting85
# [317/679] https://blog.naver.com/jiddongs831
# [318/679] https://blog.naver.com/zina_v
# [319/679] https://blog.naver.com/a_shizuru/223125164938
# [320/679] https://blog.naver.com/jetchoi
# [321/679] https://blog.naver.com/nonelily
# [322/679] https://blog.naver.com/min_story_
# [323/679] https://blog.naver.com/skalwls21
# [324/679] https://blog.naver.com/sl7856
# [325/679] https://blog.naver.com/rohabeauty
# [326/679] https://blog.naver.com/minimouse24/223860687901
# [327/679] https://blog.naver.com/as06123
# [328/679] https://blog.naver.com/wjuzi
# [329/679] https://blog.naver.com/rrsnow/223860717277
# [330/679] https://blog.naver.com/borareview/223867115718
# [331/679] https://blog.naver.com/lieni67
# [332/679] https://blog.naver.com/kes434/223926234036
# [333/679] https://blog.naver.com/rhekrud1111/224003262457
# [334/679] https://blog.naver.com/102-206
# [335/679] https://blog.naver.com/nymp18
# [336/679] https://blog.naver.com/shu__yoon
# [337/679] https://blog.naver.com/yun_delight
# [338/679] https://blog.naver.com/cutykayo
# [339/679] https://blog.naver.com/designadd032
# [340/679] https://blog.naver.com/nagi_729/223922153691
# [341/679] https://blog.naver.com/glare54168
# [342/679] https://blog.naver.com/zldnld99/223634439953
# [343/679] https://blog.naver.com/dbsgh9288
# [344/679] https://blog.naver.com/bee7817
# [345/679] https://blog.naver.com/marmoe_ar
# [346/679] https://blog.naver.com/euntill
# [347/679] https://blog.naver.com/lumukk042_ps
# [348/679] https://blog.naver.com/jmjh9282
# [349/679] https://blog.naver.com/sssord12/223676105306
# [350/679] https://blog.naver.com/intend3739
# [351/679] https://blog.naver.com/eb3522
# [352/679] https://blog.naver.com/yoj9130
# [353/679] https://blog.naver.com/sogo5824
# [354/679] https://blog.naver.com/vividlalalove
# [355/679] https://blog.naver.com/aitocdunmq3709
# [356/679] https://blog.naver.com/leejaeum
# [357/679] https://blog.naver.com/yunji678
# [358/679] https://blog.naver.com/forsy113
# [359/679] https://blog.naver.com/ballaballa0-7-0-2
# [360/679] https://blog.naver.com/shong_g
# [361/679] https://blog.naver.com/qufqlc08/224080111262
# [362/679] https://blog.naver.com/mvvm15
# [363/679] https://blog.naver.com/gguks_nayomi
# [364/679] https://blog.naver.com/noriteo98
# [365/679] https://blog.naver.com/dear_lemon
# [366/679] https://blog.naver.com/jungeun9019/224069433927
# [367/679] https://blog.naver.com/ghstmsdl10
# [368/679] https://blog.naver.com/mukdduki
# [369/679] https://blog.naver.com/cykim2402
# [370/679] https://blog.naver.com/ativeclod
# [371/679] https://blog.naver.com/hi_sat
# [372/679] https://blog.naver.com/ekgp1356
# [373/679] https://blog.naver.com/layeonparkgogo/223965242205
# [374/679] https://blog.naver.com/seelee7830
# [375/679] https://blog.naver.com/yuha220222
# [376/679] https://blog.naver.com/sweetjelly95
# [377/679] https://blog.naver.com/ssp04038/224074034668
# [378/679] https://blog.naver.com/sinabronail
# [379/679] https://blog.naver.com/minadayo0131
# [380/679] https://blog.naver.com/handding2
# [381/679] https://blog.naver.com/brightnalong
# [382/679] https://blog.naver.com/light3524
# [383/679] https://blog.naver.com/singlesmagazine/224071278544
# [384/679] https://blog.naver.com/gydel4856
# [385/679] https://blog.naver.com/18sunhong486
# [386/679] https://blog.naver.com/ccccccho_v/224070389937
# [387/679] https://blog.naver.com/yhluna0228
# [388/679] https://blog.naver.com/lolrabbit
# [389/679] https://blog.naver.com/just_do_it_bunny
# [390/679] https://blog.naver.com/formulog
# [391/679] https://blog.naver.com/me_seo_yoon
# [392/679] https://blog.naver.com/yoni_0905/223992830985
# [393/679] https://blog.naver.com/hyororiee
# [394/679] https://blog.naver.com/jsjjsj8
# [395/679] https://blog.naver.com/proseouler
# [396/679] https://blog.naver.com/hnluv1004
# [397/679] https://blog.naver.com/yhtesni03085
# [398/679] https://blog.naver.com/factxc7343
# [399/679] https://blog.naver.com/stckiqhf7165
# [400/679] https://blog.naver.com/pepekjin/224061290795
# [401/679] https://blog.naver.com/yuldoing
# [402/679] https://blog.naver.com/forsy_emartkj
# [403/679] https://blog.naver.com/levely3294/224035216326
# [404/679] https://blog.naver.com/ayiirnarzb22213
# [405/679] https://blog.naver.com/princessminha/224044065685
# [406/679] https://blog.naver.com/lxxhxxming
# [407/679] https://blog.naver.com/yeon_s2__
# [408/679] https://blog.naver.com/dwg1016
# [409/679] https://blog.naver.com/jabies
# [410/679] https://blog.naver.com/yunji678
# [411/679] https://blog.naver.com/rhekrud1111/223332528540
# [412/679] https://blog.naver.com/aobo7
# [413/679] https://blog.naver.com/iris_93_
# [414/679] https://blog.naver.com/skirt11927
# [415/679] https://blog.naver.com/qkrtmdcjftpsxja
# [416/679] https://blog.naver.com/bandinhouse_gasan
# [417/679] https://blog.naver.com/ohj809
# [418/679] https://blog.naver.com/lovineee_qhrejddl
# [419/679] https://blog.naver.com/mylovebina
# [420/679] https://blog.naver.com/lqud/224067371978
# [421/679] https://blog.naver.com/aquawhta
# [422/679] https://blog.naver.com/sooy110/222720962975
# [423/679] https://blog.naver.com/yiroum
# [424/679] https://blog.naver.com/assist6587
# [425/679] https://blog.naver.com/lovely80popo
# [426/679] https://blog.naver.com/11299/223350049498
# [427/679] https://blog.naver.com/aboutcheny
# [428/679] https://blog.naver.com/1234gkswldud
# [429/679] https://blog.naver.com/mmins-0610/223001981287
# [430/679] https://blog.naver.com/ochawonjiha
# [431/679] https://blog.naver.com/ha_game
# [432/679] https://blog.naver.com/kkongdal2/222892564525
# [433/679] https://blog.naver.com/lifeofbliss/224017609313
# [434/679] https://blog.naver.com/dodream8069
# [435/679] https://blog.naver.com/jjwjss
# [436/679] https://blog.naver.com/paul5947
# [437/679] https://blog.naver.com/rlawlgo85
# [438/679] https://blog.naver.com/chj_9171
# [439/679] https://blog.naver.com/jasin0520
# [440/679] https://blog.naver.com/cufspr
# [441/679] https://blog.naver.com/pkikimyk
# [442/679] https://blog.naver.com/f2mg1
# [443/679] https://blog.naver.com/angelasong0814/222940328545
# [444/679] https://blog.naver.com/akqjqtk232
# [445/679] https://blog.naver.com/ywsn4836
# [446/679] https://blog.naver.com/pej8581
# [447/679] https://blog.naver.com/twinklebunny/223950073402
# [448/679] https://blog.naver.com/ccwonju-11
# [449/679] https://blog.naver.com/gttwx8f8
# [450/679] https://blog.naver.com/love_juu
# [451/679] https://blog.naver.com/zzeom14/222983706620
# [452/679] https://blog.naver.com/free_beauty_/223090593970
# [453/679] https://blog.naver.com/alldaybunny/222727921550
# [454/679] https://blog.naver.com/beauty__hara
# [455/679] https://blog.naver.com/lucidamuseum
# [456/679] https://blog.naver.com/daily_soli
# [457/679] https://blog.naver.com/lavlav87
# [458/679] https://blog.naver.com/younjeong92
# [459/679] https://blog.naver.com/qufqlc08/224080111262
# [460/679] https://blog.naver.com/iti1004
# [461/679] https://blog.naver.com/lolrabbit
# [462/679] https://blog.naver.com/18sunhong486
# [463/679] https://blog.naver.com/2020228
# [464/679] https://blog.naver.com/jihyejino_o
# [465/679] https://blog.naver.com/djoin50102
# [466/679] https://blog.naver.com/proseouler
# [467/679] https://blog.naver.com/vanillalatte99
# [468/679] https://blog.naver.com/kes434/223926234036
# [469/679] https://blog.naver.com/nobleliz_
# [470/679] https://blog.naver.com/withmiyoung
# [471/679] https://blog.naver.com/higo1404/223138677242
# [472/679] https://blog.naver.com/frendlylucks
# [473/679] https://blog.naver.com/grace_blooming
# [474/679] https://blog.naver.com/happy_hworld/222796585992
# [475/679] https://blog.naver.com/star6556_
# [476/679] https://blog.naver.com/dwg1016
# [477/679] https://blog.naver.com/mongout_official
# [478/679] https://blog.naver.com/bettermom_hani
# [479/679] https://blog.naver.com/gangbjl
# [480/679] https://blog.naver.com/b_me__
# [481/679] https://blog.naver.com/diddkfla0808
# [482/679] https://blog.naver.com/huhuhaha_
# [483/679] https://blog.naver.com/u5ibt15p
# [484/679] https://blog.naver.com/namiworld_/223963958674
# [485/679] https://blog.naver.com/oriri62
# [486/679] https://blog.naver.com/alth1690
# [487/679] https://blog.naver.com/grffiti21552
# [488/679] https://blog.naver.com/bnewg
# [489/679] https://blog.naver.com/pepekjin/224061290795
# [490/679] https://blog.naver.com/hsppv9cs
# [491/679] https://blog.naver.com/subin369369
# [492/679] https://blog.naver.com/kje2134
# [493/679] https://blog.naver.com/mong2days
# [494/679] https://blog.naver.com/ajfqhsl89
# [495/679] https://blog.naver.com/sarangsnp
# [496/679] https://blog.naver.com/25artist/223948161679
# [497/679] https://blog.naver.com/crburetor82830
# [498/679] https://blog.naver.com/doublesholdings/223668442212
# [499/679] https://blog.naver.com/kkk48770
# [500/679] https://blog.naver.com/tomato627
# [501/679] https://blog.naver.com/songpinkkk
# [502/679] https://blog.naver.com/jsjjsj8
# [503/679] https://blog.naver.com/juhee4493
# [504/679] https://blog.naver.com/sbs-daejeon
# [505/679] https://blog.naver.com/mkkang55
# [506/679] https://blog.naver.com/alswn2th
# [507/679] https://blog.naver.com/gkna4141
# [508/679] https://blog.naver.com/geeeeenieee
# [509/679] https://blog.naver.com/excise74617
# [510/679] https://blog.naver.com/fly_jian/223886026289
# [511/679] https://blog.naver.com/jej2008s
# [512/679] https://blog.naver.com/dbfkd93
# [513/679] https://blog.naver.com/wjddla402
# [514/679] https://blog.naver.com/sospring123
# [515/679] https://blog.naver.com/mariahoho
# [516/679] https://blog.naver.com/prim-rose
# [517/679] https://blog.naver.com/udts12
# [518/679] https://blog.naver.com/sohocinema
# [519/679] https://blog.naver.com/blue27j
# [520/679] https://blog.naver.com/sunnysmiles11505
# [521/679] https://blog.naver.com/gncnfkrl
# [522/679] https://blog.naver.com/wbal0707
# [523/679] https://blog.naver.com/sukna0228/223968021868
# [524/679] https://blog.naver.com/felicitous85
# [525/679] https://blog.naver.com/cody1121
# [526/679] https://blog.naver.com/esther40827
# [527/679] https://blog.naver.com/south1346
# [528/679] https://blog.naver.com/intro14
# [529/679] https://blog.naver.com/llhhss83_
# [530/679] https://blog.naver.com/dhsmfgkfngodqhr
# [531/679] https://blog.naver.com/jiizyy
# [532/679] https://blog.naver.com/happyhome1076
# [533/679] https://blog.naver.com/beauty_byelin
# [534/679] https://blog.naver.com/kbr960528
# [535/679] https://blog.naver.com/jungipower98
# [536/679] https://blog.naver.com/tororo1174
# [537/679] https://blog.naver.com/newdlwlsdn17
# [538/679] https://blog.naver.com/djnm312
# [539/679] https://blog.naver.com/technolhs
# [540/679] https://blog.naver.com/xiangoei333
# [541/679] https://blog.naver.com/tntnjini-
# [542/679] https://blog.naver.com/hoyamom_
# [543/679] https://blog.naver.com/fresh22j
# [544/679] https://blog.naver.com/hhott60f
# [545/679] https://blog.naver.com/vnfmsakdmfdk
# [546/679] https://blog.naver.com/sjw121116
# [547/679] https://blog.naver.com/beensoop_
# [548/679] https://blog.naver.com/yooj228
# [549/679] https://blog.naver.com/sansang00
# [550/679] https://blog.naver.com/ra0215
# [551/679] https://blog.naver.com/semsot
# [552/679] https://blog.naver.com/rhekrud1111/224003262457
# [553/679] https://blog.naver.com/dmsrud9921
# [554/679] https://blog.naver.com/kiddy28/223594030427
# [555/679] https://blog.naver.com/sgclthxfkvm
# [556/679] https://blog.naver.com/choiseou
# [557/679] https://blog.naver.com/slovejy
# [558/679] https://blog.naver.com/lnc32002
# [559/679] https://blog.naver.com/aeyoni
# [560/679] https://blog.naver.com/chois909/224081066778
# [561/679] https://blog.naver.com/melrosequeen
# [562/679] https://blog.naver.com/fobtoeirav33237
# [563/679] https://blog.naver.com/4chi_27
# [564/679] https://blog.naver.com/125_suu/223266643417
# [565/679] https://blog.naver.com/jinah0213
# [566/679] https://blog.naver.com/ians211/223934634119
# [567/679] https://blog.naver.com/pppmh0827/223967600257
# [568/679] https://blog.naver.com/lsosvbe7/223963457368
# [569/679] https://blog.naver.com/onj0808/224027672881
# [570/679] https://blog.naver.com/zzeom14/223259178439
# [571/679] https://blog.naver.com/todrlclfm97
# [572/679] https://blog.naver.com/viviankk
# [573/679] https://blog.naver.com/fallrain94
# [574/679] https://blog.naver.com/sesehhh/224065804459
# [575/679] https://blog.naver.com/rohabeauty
# [576/679] https://blog.naver.com/f2mg1
# [577/679] https://blog.naver.com/yunji678
# [578/679] https://blog.naver.com/banidad
# [579/679] https://blog.naver.com/kim_toggi
# [580/679] https://blog.naver.com/rrsnow/223860717277
# [581/679] https://blog.naver.com/nonelily
# [582/679] https://blog.naver.com/ksmember
# [583/679] https://blog.naver.com/algus744
# [584/679] https://blog.naver.com/nagi96/223839540863
# [585/679] https://blog.naver.com/da-sool
# [586/679] https://blog.naver.com/cfs898
# [587/679] https://blog.naver.com/molly32
# [588/679] https://blog.naver.com/1ovest
# [589/679] https://blog.naver.com/vd_r1
# [590/679] https://blog.naver.com/4646__
# [591/679] https://blog.naver.com/akrkqo
# [592/679] https://blog.naver.com/har0913
# [593/679] https://blog.naver.com/lqud/224067371978
# [594/679] https://blog.naver.com/sk3374
# [595/679] https://blog.naver.com/iamscalet
# [596/679] https://blog.naver.com/kjiwon1018
# [597/679] https://blog.naver.com/olivia9532
# [598/679] https://blog.naver.com/yunautumn_
# [599/679] https://blog.naver.com/j_soluvly
# [600/679] https://blog.naver.com/blackholecd/223668813871
# [601/679] https://blog.naver.com/i486usaprice/223406888283
# [602/679] https://blog.naver.com/youridalbit/223669999778
# [603/679] https://blog.naver.com/aobo7
# [604/679] https://blog.naver.com/pej8581
# [605/679] https://blog.naver.com/bbekimha/223595604453
# [606/679] https://blog.naver.com/soenaaa/223596329453
# [607/679] https://blog.naver.com/k_159500/223650595937
# [608/679] https://blog.naver.com/qufzhd12/223563893222
# [609/679] https://blog.naver.com/wilklove
# [610/679] https://blog.naver.com/forever2131/223596380427
# [611/679] https://blog.naver.com/ujoonote/223597236484
# [612/679] https://blog.naver.com/thregitong/223596928144
# [613/679] https://blog.naver.com/ryuel5
# [614/679] https://blog.naver.com/supia2728/223865760819
# [615/679] https://blog.naver.com/pkikimyk
# [616/679] https://blog.naver.com/tk2o2254
# [617/679] https://blog.naver.com/haejinryu
# [618/679] https://blog.naver.com/btpp77
# [619/679] https://blog.naver.com/mukdduki
# [620/679] https://blog.naver.com/kdseul33
# [621/679] https://blog.naver.com/gguks_nayomi
# [622/679] https://blog.naver.com/dolphinlog
# [623/679] https://blog.naver.com/godus7111
# [624/679] https://blog.naver.com/dailychuuu
# [625/679] https://blog.naver.com/neeeeewjin1
# [626/679] https://blog.naver.com/singlesmagazine/224071278544
# [627/679] https://blog.naver.com/sppksy
# [628/679] https://blog.naver.com/sbs-6218600
# [629/679] https://blog.naver.com/formulog
# [630/679] https://blog.naver.com/tldkaksnf062
# [631/679] https://blog.naver.com/yuldoing
# [632/679] https://blog.naver.com/ccccccho_v/224070389937
# [633/679] https://blog.naver.com/nobleliz_
# [634/679] https://blog.naver.com/dwg1016
# [635/679] https://blog.naver.com/njuiwwik/224010524438
# [636/679] https://blog.naver.com/gpwl9747
# [637/679] https://blog.naver.com/mini_kkobugi
# [638/679] https://blog.naver.com/johappy1128
# [639/679] https://blog.naver.com/ekdusld910111/224029667523
# [640/679] https://blog.naver.com/rlatndus32
# [641/679] https://blog.naver.com/zq2pdcbj8eo5tx_
# [642/679] https://blog.naver.com/lxxhxxming
# [643/679] https://blog.naver.com/hj0301_
# [644/679] https://blog.naver.com/j_01_20
# [645/679] https://blog.naver.com/camelia96/224017779230
# [646/679] https://blog.naver.com/haeunnison
# [647/679] https://blog.naver.com/blingbling_mj
# [648/679] https://blog.naver.com/extraordinary5873
# [649/679] https://blog.naver.com/thumbnail2021
# [650/679] https://blog.naver.com/minyunni/223988288297
# [651/679] https://blog.naver.com/1gydud
# [652/679] https://blog.naver.com/daisy-3396
# [653/679] https://blog.naver.com/youngnotes
# [654/679] https://blog.naver.com/ekrlls0913
# [655/679] https://blog.naver.com/return132856
# [656/679] https://blog.naver.com/cherrytue/223573311856
# [657/679] https://blog.naver.com/piano9979/224059181202
# [658/679] https://blog.naver.com/mydiary030
# [659/679] https://blog.naver.com/ella_holiday
# [660/679] https://blog.naver.com/hn524049
# [661/679] https://blog.naver.com/kyj5141
# [662/679] https://blog.naver.com/day__2
# [663/679] https://blog.naver.com/achyhl87
# [664/679] https://blog.naver.com/dadamon330
# [665/679] https://blog.naver.com/ojs419
# [666/679] https://blog.naver.com/doublesholdings/223863365493
# [667/679] https://blog.naver.com/neither561687
# [668/679] https://blog.naver.com/euddeum5357
# [669/679] https://blog.naver.com/eunj3690
# [670/679] https://blog.naver.com/romang2good
# [671/679] https://blog.naver.com/serendipity_820
# [672/679] https://blog.naver.com/baeena95
# [673/679] https://blog.naver.com/ddodong1224
# [674/679] https://blog.naver.com/truckuo65
# [675/679] https://blog.naver.com/armaa41
# [676/679] https://blog.naver.com/new_98
# [677/679] https://blog.naver.com/aurora200568
# [678/679] https://blog.naver.com/namcheol223
# [679/679] https://blog.naver.com/euntill

# %% [markdown]
# ### CSV 저장

# %%
### CSV 저장
if IS_SAVE_CSV:
    os.makedirs(ROOT_DOWNLOAD_DIR, exist_ok=True)
    df_enriched.to_csv(CSV_PATH, index=False, encoding="utf-8-sig")
    print("CSV 저장 완료:", CSV_PATH)
# Out:
# CSV 저장 완료: craw-download-file\20251120_02_multi.csv
